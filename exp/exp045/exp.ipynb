# %% [markdown]
# # exp045

# %%
import os
import sys
import gc
import itertools
import pickle
import pathlib
import datetime
from dateutil.relativedelta import relativedelta
from dotenv import load_dotenv
load_dotenv()
sys.path.append(os.getenv('UTILS_PATH'))

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

import line_notify

# %%
import builtins
import types

def imports():
    for name, val in globals().items():
        # module imports
        if isinstance(val, types.ModuleType):
            yield name, val

            # functions / callables
        if hasattr(val, '__call__'):
            yield name, val


def noglobal(f):
    '''
    ref: https://gist.github.com/raven38/4e4c3c7a179283c441f575d6e375510c
    '''
    return types.FunctionType(f.__code__,
                              dict(imports()),
                              f.__name__,
                              f.__defaults__,
                              f.__closure__
                              )

# %%
SEED = 42
RUN_INF = True # 推論処理を行うか
BATCH_SIZE = int(5e5)

# %%
Ns = {}
Ns['cf_a'] = 12
Ns['ctf_a'] = 12
Ns['atfd_a'] = 12
Ns['atfp_a'] = 12
Ns['pa_a'] = 12

Ns['cf_w'] = 12
Ns['ctf_w'] = 12
Ns['atfd_w'] = 12
Ns['atfp_w'] = 12
Ns['pa_w'] = 12

Ns['cf_m'] = 12
Ns['ctf_m'] = 12
Ns['atfd_m'] = 12
Ns['atfp_m'] = 12
Ns['pa_m'] = 12

Ns['cf_y'] = 12
Ns['ctf_y'] = 12
Ns['atfd_y'] = 12
Ns['atfp_y'] = 12
Ns['pa_y'] = 12

# %% [markdown]
# ディレクトリ設定

# %%
INPUT_DIR = os.getenv('INPUT_DIR')
OUTPUT_DIR = os.getenv('OUTPUT_DIR')
#exp_name = os.path.dirname(__file__).split('/')[-1]
exp_name = 'exp045'
os.makedirs(OUTPUT_DIR + exp_name, exist_ok=True)

# %% [markdown]
# データ読み込み

# %%
articles = pd.read_csv(INPUT_DIR + 'articles.csv', dtype='object')
customers = pd.read_csv(INPUT_DIR + 'customers.csv')
transactions = pd.read_csv(INPUT_DIR + 'transactions_train.csv', dtype={'article_id':'str'}, parse_dates=['t_dat'])
sample = pd.read_csv(INPUT_DIR + 'sample_submission.csv')

# %%
first_week_sales_pred = pd.read_csv(OUTPUT_DIR + '1st_week_sales_pred/result.csv', dtype={'article_id':'str'},  parse_dates=['1st_week_sales_dat'])

# %% [markdown]
# # 前処理

# %%
ALL_CUSTOMER = customers['customer_id'].unique().tolist()
ALL_ARTICLE = articles['article_id'].unique().tolist()

customer_ids = dict(list(enumerate(ALL_CUSTOMER)))
article_ids = dict(list(enumerate(ALL_ARTICLE)))

customer_map = {u: uidx for uidx, u in customer_ids.items()}
article_map = {i: iidx for iidx, i in article_ids.items()}

articles['article_id'] = articles['article_id'].map(article_map)
customers['customer_id'] = customers['customer_id'].map(customer_map)
transactions['article_id'] = transactions['article_id'].map(article_map)
transactions['customer_id'] = transactions['customer_id'].map(customer_map)
sample['customer_id'] = sample['customer_id'].map(customer_map)
first_week_sales_pred['article_id'] = first_week_sales_pred['article_id'].map(article_map)

# %%
# 名寄せ
customers['fashion_news_frequency'] = customers['fashion_news_frequency'].str.replace('None','NONE')

# %%
customers['age10'] = str((customers['age'] // 10) * 10)
customers.loc[customers['age'].isnull(), 'age10'] = np.nan

# %%
# label_encoding
le_cols = ['product_type_name', 'product_group_name', 'graphical_appearance_name',
            'colour_group_name', 'perceived_colour_value_name', 'perceived_colour_master_name', 'department_name',
            'index_name', 'index_group_name', 'section_name', 'garment_group_name']
for c in le_cols:
    le = LabelEncoder()
    articles[c] = le.fit_transform(articles[c].fillna(''))


le_cols = ['club_member_status', 'fashion_news_frequency', 'postal_code', 'age10']
for c in le_cols:
    le = LabelEncoder()
    customers[c] = le.fit_transform(customers[c].fillna(''))

# %%
customers['customer_type'] = customers['FN'].fillna(0).astype(int).astype(str) + \
                             customers['Active'].fillna(0).astype(int).astype(str) + \
                             customers['club_member_status'].fillna(0).astype(int).astype(str) + \
                             customers['fashion_news_frequency'].fillna(0).astype(int).astype(str) + \
                             customers['age10'].fillna(0).astype(int).astype(str)

le = LabelEncoder()
customers['customer_type'] = le.fit_transform(customers['customer_type'])

# %%
# transactionに紐づけ
transactions = transactions.merge(customers, on='customer_id', how='left')
transactions = transactions.merge(articles, on='article_id', how='left')

# %%
# 学習データの作成
# 1週ずつローリングして学習データを生成
train_start = '2020-09-09'
valid_start = '2020-09-16'
valid_end = '2020-09-22'

n_iter = 1
hist_st = train_start
target_st = valid_start
ml_train = pd.DataFrame()

for i in range(n_iter):
    history_tran = transactions[transactions['t_dat'] < hist_st].copy()
    target_tran = transactions[(transactions['t_dat'] >= hist_st) & (transactions['t_dat'] < target_st)].copy()

    target_id = target_tran['customer_id'].unique().tolist()

# %% [markdown]
# # データセット作成（レコメンド→対象データセット作成→特徴量エンジニアリング）

# %%
@noglobal
def get_customer_frequent(history, n=12, timedelta=None):
    """顧客ごと商品の購入数をカウントし上位の商品を抽出

    Args:
        history (dataframe): 集計対象の実績データ
        n (int): レコメンド対象とする数
        timedelta (dateutil.relativedelta): 指定された場合、実績データの終端からtimedelta分のデータを取得する

    Returns:
        dataframe: 抽出結果
    """
    if timedelta is not None:
        st_date = history['t_dat'].max() - timedelta
        history = history[history['t_dat']>=st_date].copy()
        
    customer_agg = history.groupby(['customer_id', 'article_id'])['t_dat'].count().reset_index()
    customer_agg = customer_agg.rename(columns={'t_dat':'cnt'})
    customer_agg = customer_agg.sort_values(['customer_id', 'cnt'], ascending=False)
    result = customer_agg.groupby('customer_id').head(n)
    return result[['customer_id', 'article_id']]

@noglobal
def get_popular_article(history, n=12, timedelta=None):
    """全体の購入数をカウントし上位の商品を抽出

    Args:
        history (dataframe): 集計対象の実績データ
        n (int): レコメンド対象とする数
        timedelta (dateutil.relativedelta): 指定された場合、実績データの終端からtimedelta分のデータを取得する

    Returns:
        list: 抽出結果
    """
    # 全体の購入数量
    if timedelta is not None:
        st_date = history['t_dat'].max() - timedelta
        history = history[history['t_dat']>=st_date].copy()

    total_agg = history.groupby('article_id')['t_dat'].count().reset_index()
    total_agg = total_agg.rename(columns={'t_dat':'cnt'})
    total_agg = total_agg.sort_values(['cnt'], ascending=False)
    total_agg = total_agg.head(n)
    result = list(total_agg['article_id'].values)
    return result

@noglobal
def get_customer_type_frequent(history, n=12, timedelta=None):
    if timedelta is not None:
        st_date = history['t_dat'].max() - timedelta
        history = history[history['t_dat']>=st_date].copy()

    result = history[['customer_id', 'customer_type']].drop_duplicates().copy()
    agg = history.groupby(['customer_type', 'article_id'])['t_dat'].count().reset_index()
    agg = agg.rename(columns={'t_dat':'cnt'})
    agg = agg.sort_values(['customer_type', 'cnt'], ascending=False)
    agg = agg.groupby('customer_type').head(n)
    result = result.merge(agg[['customer_type', 'article_id']], on='customer_type', how='left')
    return result[['customer_id', 'article_id']]

@noglobal
def get_article_type_frequent(history, col, n=12, timedelta=None):
    if timedelta is not None:
        st_date = history['t_dat'].max() - timedelta
        history = history[history['t_dat']>=st_date].copy()

    result = history.groupby(['customer_id', col])['t_dat'].count().reset_index()
    result = result.rename(columns={'t_dat':'cnt'})
    result = result.sort_values(['customer_id', 'cnt'], ascending=False)
    result = result.groupby(['customer_id']).head(1)[['customer_id', col]]

    agg = history.groupby([col, 'article_id'])['t_dat'].count().reset_index()
    agg = agg.rename(columns={'t_dat':'cnt'})
    agg = agg.sort_values([col, 'cnt'], ascending=False)
    agg = agg.groupby(col).head(n)
    result = result.merge(agg[[col, 'article_id']], on=col, how='left')
    return result[['customer_id', 'article_id']]

@noglobal
def get_popular_new_article(first_week_sales_pred, n=12):
    """新商品の初週売り上げ予測が高い商品を抽出
    """
    first_week_sales_pred = first_week_sales_pred.sort_values(['1st_week_sales_pred'], ascending=False)
    first_week_sales_pred = first_week_sales_pred.head(n)
    result = list(first_week_sales_pred['article_id'].values)
    return result

@noglobal
def get_reccomend(target_customer_id, history, Ns, first_week_sales_pred):
    n = 12
    result = pd.DataFrame()
    

    td = None
    result = result.append(get_customer_frequent(history, Ns['cf_a'], td))
    result = result.append(get_customer_type_frequent(history, Ns['ctf_a'], td))
    result = result.append(get_article_type_frequent(history, 'department_name', Ns['atfd_a'], td))
    result = result.append(get_article_type_frequent(history, 'perceived_colour_master_name', Ns['atfp_a'], td))
    popular_article = get_popular_article(history, Ns['pa_a'], td)
    # customerとpopular articleの全組み合わせでdataframe作成
    popular_article = pd.DataFrame(itertools.product(target_customer_id, popular_article), columns=['customer_id', 'article_id'])
    result = result.append(popular_article)

    popular_new_article = get_popular_new_article(first_week_sales_pred)
    popular_new_article = pd.DataFrame(itertools.product(target_customer_id, popular_new_article), columns=['customer_id', 'article_id'])
    result = result.append(popular_new_article)

    result = result.drop_duplicates()

    td = relativedelta(weeks=1)
    result = result.append(get_customer_frequent(history, Ns['cf_w'], td))
    result = result.append(get_customer_type_frequent(history, Ns['ctf_w'], td))
    result = result.append(get_article_type_frequent(history, 'department_name', Ns['atfd_w'], td))
    result = result.append(get_article_type_frequent(history, 'perceived_colour_master_name', Ns['atfp_w'], td))
    popular_article = get_popular_article(history, Ns['pa_w'], td)
    # customerとpopular articleの全組み合わせでdataframe作成
    popular_article = pd.DataFrame(itertools.product(target_customer_id, popular_article), columns=['customer_id', 'article_id'])
    result = result.append(popular_article)
    result = result.drop_duplicates()

    td = relativedelta(months=1)
    result = result.append(get_customer_frequent(history, Ns['cf_m'], td))
    result = result.append(get_customer_type_frequent(history, Ns['ctf_m'], td))
    result = result.append(get_article_type_frequent(history, 'department_name', Ns['atfd_m'], td))
    result = result.append(get_article_type_frequent(history, 'perceived_colour_master_name', Ns['atfp_m'], td))
    popular_article = get_popular_article(history, Ns['pa_m'], td)
    # customerとpopular articleの全組み合わせでdataframe作成
    popular_article = pd.DataFrame(itertools.product(target_customer_id, popular_article), columns=['customer_id', 'article_id'])
    result = result.append(popular_article)
    result = result.drop_duplicates()

    td = relativedelta(years=1)
    result = result.append(get_customer_frequent(history, Ns['cf_y'], td))
    result = result.append(get_customer_type_frequent(history, Ns['ctf_y'], td))
    result = result.append(get_article_type_frequent(history, 'department_name', Ns['atfd_y'], td))
    result = result.append(get_article_type_frequent(history, 'perceived_colour_master_name', Ns['atfp_y'], td))
    popular_article = get_popular_article(history, Ns['pa_y'], td)
    # customerとpopular articleの全組み合わせでdataframe作成
    popular_article = pd.DataFrame(itertools.product(target_customer_id, popular_article), columns=['customer_id', 'article_id'])
    result = result.append(popular_article)
    result = result.drop_duplicates()

    result = result[result['customer_id'].isin(target_customer_id)].copy()

    return result

# %%
@noglobal
def add_labels(recom_result, history):
    """レコメンドしたデータが学習期間で購入されたかどうかのフラグを付与する

    Args:
        recom_result (_type_): レコメンド結果
        train_tran (_type_): 学習期間のトランザクションデータ

    Returns:
        _type_: 学習期間での購入フラグを付与したレコメンド結果
    """
    history = history[['customer_id', 'article_id']].drop_duplicates()
    history['buy'] = 1
    recom_result = recom_result.merge(history, on=['customer_id', 'article_id'], how='left')
    recom_result['buy'] = recom_result['buy'].fillna(0)
    return recom_result

# %%
@noglobal
def make_article_features(articles):
    cols = ['product_type_name', 'product_group_name', 'graphical_appearance_name',
            'colour_group_name', 'perceived_colour_value_name', 'perceived_colour_master_name', 'department_name',
            'index_name', 'index_group_name', 'section_name', 'garment_group_name']
    return articles[['article_id']+cols]

@noglobal
def make_article_tran_features(history):
    df = history.groupby('article_id').agg({'t_dat':['count', 'max', 'min'],
                                            'price':['max', 'min', 'mean'], 
                                            'age':['max', 'min', 'mean', 'std']}).reset_index()
    df.columns = ['article_id','article_total_cnt', 'article_total_latest_buy', 'article_total_1st_buy', 'article_price_max', 'article_price_min', 'article_price_mean', 'article_age_max', 'article_age_min', 'article_age_mean', 'article_age_std']
    df['article_total_1st_buy'] = (history['t_dat'].max() - df['article_total_1st_buy']).dt.days
    df['article_total_latest_buy'] = (history['t_dat'].max() - df['article_total_latest_buy']).dt.days

    history_1weekago = history.loc[(history['t_dat'] > history['t_dat'].max() - relativedelta(days=7)) & 
                                   (history['t_dat'] <= history['t_dat'].max())]

    history_1weekago_df = history_1weekago.groupby('article_id').agg({'t_dat':['count', 'max', 'min'],
                                            'price':['max', 'min', 'mean'], 
                                            'age':['max', 'min', 'mean', 'std', 'median']}).reset_index()
    history_1weekago_df.columns = ['article_id','article_total_cnt_1weekago', 'article_total_latest_buy_1weekago', 'article_total_1st_buy_1weekago', 'article_price_max_1weekago', 'article_price_min_1weekago', 'article_price_mean_1weekago', 'article_age_max_1weekago', 'article_age_min_1weekago', 'article_age_mean_1weekago', 'article_age_std_1weekago', 'article_age_median_1weekago']
    history_1weekago_df['article_total_1st_buy_1weekago'] = (history_1weekago['t_dat'].max() - history_1weekago_df['article_total_1st_buy_1weekago']).dt.days
    history_1weekago_df['article_total_latest_buy_1weekago'] = (history_1weekago['t_dat'].max() - history_1weekago_df['article_total_latest_buy_1weekago']).dt.days

    df = pd.merge(df,history_1weekago_df,how='left',on='article_id')

    del history_1weekago, history_1weekago_df
    gc.collect()

    history_2weekago = history.loc[(history['t_dat'] > history['t_dat'].max() - relativedelta(days=14)) & 
                                   (history['t_dat'] <= history['t_dat'].max() - relativedelta(days=7))]

    history_2weekago_df = history_2weekago.groupby('article_id').agg({'t_dat':['count', 'max', 'min'],
                                            'price':['max', 'min', 'mean'], 
                                            'age':['max', 'min', 'mean', 'std', 'median']}).reset_index()
    history_2weekago_df.columns = ['article_id','article_total_cnt_2weekago', 'article_total_latest_buy_2weekago', 'article_total_1st_buy_2weekago', 'article_price_max_2weekago', 'article_price_min_2weekago', 'article_price_mean_2weekago', 'article_age_max_2weekago', 'article_age_min_2weekago', 'article_age_mean_2weekago', 'article_age_std_2weekago', 'article_age_median_2weekago']
    history_2weekago_df['article_total_1st_buy_2weekago'] = (history_2weekago['t_dat'].max() - history_2weekago_df['article_total_1st_buy_2weekago']).dt.days
    history_2weekago_df['article_total_latest_buy_2weekago'] = (history_2weekago['t_dat'].max() - history_2weekago_df['article_total_latest_buy_2weekago']).dt.days

    df = pd.merge(df,history_2weekago_df,how='left',on='article_id')

    del history_2weekago, history_2weekago_df
    gc.collect()

    return df


@noglobal
def make_customer_features(customers):
    return customers

@noglobal
def make_customer_tran_features(history):
    group = ['Ladieswear', 'Divided', 'Menswear', 'Sport', 'Baby/Children']
    for g in group:
        history[g] = 0
        history.loc[history['index_group_name']==g, g] = 1


    df = history.groupby('customer_id').agg({'t_dat':['count', 'max', 'min'],
                                            'price':['max', 'min', 'mean'],
                                            'Ladieswear':'sum',
                                            'Divided':'sum',
                                            'Menswear':'sum',
                                            'Sport':'sum',
                                            'Baby/Children':'sum'}).reset_index()
    df.columns = ['customer_id','customer_total_cnt', 'customer_total_latest_buy', 'customer_total_1st_buy', 
                  'customer_price_max', 'customer_price_min', 'customer_price_mean',
                  'Ladieswear', 'Divided', 'Menswear', 'Sport', 'Baby/Children']
    df['customer_total_1st_buy'] = (history['t_dat'].max() - df['customer_total_1st_buy']).dt.days
    df['customer_total_latest_buy'] = (history['t_dat'].max() - df['customer_total_latest_buy']).dt.days

    for g in group:
        df[g] = df[g] / df['customer_total_cnt']

#####################iida_exp24#########################
    history_1weekago = history.loc[(history['t_dat'] > history['t_dat'].max() - relativedelta(days=7)) & 
                                   (history['t_dat'] <= history['t_dat'].max())]
    history_1weekago_df =  history_1weekago.groupby('customer_id').agg({'t_dat':['count', 'max', 'min'],
                                            'price':['max', 'min', 'mean'],
                                            'Ladieswear':'sum',
                                            'Divided':'sum',
                                            'Menswear':'sum',
                                            'Sport':'sum',
                                            'Baby/Children':'sum'}).reset_index() 
    history_1weekago_df.columns = ['customer_id','customer_total_cnt_1weekago', 'customer_total_latest_buy_1weekago', 'customer_total_1st_buy_1weekago', 
                                'customer_price_max_1weekago', 'customer_price_min_1weekago', 'customer_price_mean_1weekago',
                                'Ladieswear_1weekago', 'Divided_1weekago', 'Menswear_1weekago', 'Sport_1weekago', 'Baby/Children_1weekago']

    history_1weekago_df['customer_total_1st_buy_1weekago'] = (history_1weekago['t_dat'].max() - history_1weekago_df['customer_total_1st_buy_1weekago']).dt.days
    history_1weekago_df['customer_total_latest_buy_1weekago'] = (history_1weekago['t_dat'].max() - history_1weekago_df['customer_total_latest_buy_1weekago']).dt.days

    for g in group:
        history_1weekago_df[g+'_1weekago'] = history_1weekago_df[g+'_1weekago'] / history_1weekago_df['customer_total_cnt_1weekago']

    df = pd.merge(df,history_1weekago_df,how='left',on='customer_id')

    history_2weekago = history.loc[(history['t_dat'] > history['t_dat'].max() - relativedelta(days=14)) & 
                                   (history['t_dat'] <= history['t_dat'].max() - relativedelta(days=7))]
    history_2weekago_df =  history_2weekago.groupby('customer_id').agg({'t_dat':['count', 'max', 'min'],
                                            'price':['max', 'min', 'mean'],
                                            'Ladieswear':'sum',
                                            'Divided':'sum',
                                            'Menswear':'sum',
                                            'Sport':'sum',
                                            'Baby/Children':'sum'}).reset_index() 
    history_2weekago_df.columns = ['customer_id','customer_total_cnt_2weekago', 'customer_total_latest_buy_2weekago', 'customer_total_1st_buy_2weekago', 
                                'customer_price_max_2weekago', 'customer_price_min_2weekago', 'customer_price_mean_2weekago',
                                'Ladieswear_2weekago', 'Divided_2weekago', 'Menswear_2weekago', 'Sport_2weekago', 'Baby/Children_2weekago']

    history_2weekago_df['customer_total_1st_buy_2weekago'] = (history_2weekago['t_dat'].max() - history_2weekago_df['customer_total_1st_buy_2weekago']).dt.days
    history_2weekago_df['customer_total_latest_buy_2weekago'] = (history_2weekago['t_dat'].max() - history_2weekago_df['customer_total_latest_buy_2weekago']).dt.days

    for g in group:
        history_2weekago_df[g+'_2weekago'] = history_2weekago_df[g+'_2weekago'] / history_2weekago_df['customer_total_cnt_2weekago']

    df = pd.merge(df,history_2weekago_df,how='left',on='customer_id')

    del history_2weekago, history_2weekago_df
    gc.collect()

    return df

@noglobal
def make_customer_article_features(target, history):
    df = target.merge(history, on=['customer_id', 'article_id'], how='inner')
    df = df.groupby(['customer_id', 'article_id']).agg({'t_dat':['count', 'min', 'max']}).reset_index()
    df.columns = ['customer_id', 'article_id', 'count', '1st_buy_date_diff', 'latest_buy_date_diff']
    df['1st_buy_date_diff'] = (history['t_dat'].max() - df['1st_buy_date_diff']).dt.days
    df['latest_buy_date_diff'] = (history['t_dat'].max() - df['latest_buy_date_diff']).dt.days
    return df

@noglobal
def add_same_article_type_rate(target, history, col):
    add_data = history[['customer_id', col]].copy()
    add_data['total'] = add_data.groupby('customer_id').transform('count')
    add_data = add_data.groupby(['customer_id', col])['total'].agg(['max', 'count']).reset_index()
    add_data[f'{col}_customer_buy_rate'] = add_data['count'] / add_data['max']
    target = target.merge(add_data[['customer_id', col, f'{col}_customer_buy_rate']], on=['customer_id', col], how='left')
    return target

@noglobal
def make_new_article_features(first_week_sales_pred):
    first_week_sales_pred['new_article'] = 1
    return first_week_sales_pred[['article_id', 'new_article', '1st_week_sales_pred']]
    

@noglobal
def add_features(df, history, articles, customers, first_week_sales_pred):
    df = df.merge(make_article_features(articles), on=['article_id'], how='left')
    df = df.merge(make_article_tran_features(history), on=['article_id'], how='left')
    df = df.merge(make_customer_features(customers), on=['customer_id'], how='left')
    df = df.merge(make_customer_tran_features(history), on=['customer_id'], how='left')
    df = df.merge(make_customer_article_features(df[['customer_id', 'article_id']], history), on=['article_id', 'customer_id'], how='left')
    df = df.merge(make_new_article_features(first_week_sales_pred), on=['article_id'], how='left')

    cols = ['product_type_name', 'product_group_name', 'graphical_appearance_name',
            'colour_group_name', 'perceived_colour_value_name', 'perceived_colour_master_name', 'department_name',
            'index_name', 'index_group_name', 'section_name', 'garment_group_name']

    for c in cols:
        df = add_same_article_type_rate(df, history, c)

    return df

# %% [markdown]
# # レコメンド商品を購入するかどうかの2値分類モデル

# %%
def apk(y_true, y_pred, K=12):
    assert(len(y_true) == len(y_pred))
    apks = []
    for idx in range(len(y_true)):
        y_i_true = y_true[idx]
        y_i_pred = y_pred[idx]

        # 予測値の数と重複の確認
        assert(len(y_i_pred) <= K)
        assert(len(np.unique(y_i_pred)) == len(y_i_pred))

        sum_precision = 0.0
        num_hits = 0.0

        for i, p in enumerate(y_i_pred):
            if p in y_i_true:
                num_hits += 1
                precision = num_hits / (i+1)
                sum_precision += precision
        apk = sum_precision / min(len(y_i_true), K)
        apks.append(apk)
    return apks

# %%
# 学習データの作成
# 1週ずつローリングして学習データを生成
train_start = '2020-09-09'
valid_start = '2020-09-16'
valid_end = '2020-09-22'

ml_train = pd.read_csv(OUTPUT_DIR + f'exp043/ml_train.csv')
ml_valid = pd.read_csv(OUTPUT_DIR + f'exp043/ml_valid.csv')

query_train = ml_train['customer_id'].value_counts().sort_index()
ml_train = ml_train.sort_values('customer_id').reset_index(drop=True)

query_valid = ml_valid['customer_id'].value_counts().sort_index()
ml_valid = ml_valid.sort_values('customer_id').reset_index(drop=True)

# %%
params = {
    'objective': 'lambdarank',
    'metric': 'ndcg',
    'learning_rate': 0.01,
    'ndcg_eval_at': [12],
    'n_estimators': 10000,
    'boosting_type': 'gbdt',
    'random_state': SEED,
    'feature_pre_filter': False,
    'lambda_l1': 2.652545580792273e-07,
    'lambda_l2': 4.127044972448657e-07,
    'num_leaves': 100,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.7235734670479185,
    'bagging_freq': 1,
    'min_child_samples': 100
}

# %%
N_SEED = 9

# %%
# model生成
target = 'buy'
not_use_cols = ['customer_id', 'article_id', target]
features = [c for c in ml_train.columns if c not in not_use_cols]
fi = pd.DataFrame()
vl_pred = np.zeros(len(ml_valid))
scores = []

# 学習用データ作成
tr_x, tr_y = ml_train[features], ml_train[target]
vl_x, vl_y = ml_valid[features], ml_valid[target]
tr_data = lgb.Dataset(tr_x, label=tr_y, group=query_train)
vl_data = lgb.Dataset(vl_x, label=vl_y, group=query_valid)

# 正解データ作成
valid = transactions[(transactions['t_dat'] >= valid_start) & (transactions['t_dat'] <= valid_end)].copy()
valid = valid[['customer_id', 'article_id']].drop_duplicates()
valid = valid.groupby('customer_id')['article_id'].apply(list).reset_index()
valid = valid.sort_values('customer_id').reset_index(drop=True)

for i in range(N_SEED):
    params['seed'] = i

    model = lgb.train(params, tr_data, valid_sets=[tr_data, vl_data],
                      num_boost_round=20000, early_stopping_rounds=100,verbose_eval=10)

    # 特徴量重要度
    fi_tmp = pd.DataFrame()
    fi_tmp['feature'] = model.feature_name()
    fi_tmp['importance'] = model.feature_importance(importance_type='gain')
    fi_tmp['iter'] = i
    fi = fi.append(fi_tmp)

    # cv
    vl_pred += model.predict(vl_x, num_iteration=model.best_iteration)

    # 2値分類の出力を元に12個選定
    valid_pred = ml_valid[['customer_id', 'article_id']].copy()
    valid_pred['prob'] = vl_pred
    valid_pred = valid_pred.sort_values(['customer_id', 'prob'], ascending=False)
    valid_pred = valid_pred.groupby('customer_id').head(12)
    valid_pred = valid_pred.groupby('customer_id')['article_id'].apply(list).reset_index()
    valid_pred = valid_pred.sort_values('customer_id').reset_index(drop=True)
    assert(valid['customer_id'].tolist() == valid_pred['customer_id'].tolist())
    # MAP@12
    score = np.mean(apk(valid['article_id'].tolist(), valid_pred['article_id'].tolist()))
    scores.append(score)

    print(i, score)

    with open(OUTPUT_DIR + f'{exp_name}/model{i}.pickle', 'wb') as f:
        pickle.dump(model, f)

ml_valid['pred'] = vl_pred
ml_valid.to_csv(OUTPUT_DIR + f'{exp_name}/{exp_name}_oof.csv', index=False)

print(f'MAP@12 : ' + '{:.5f}'.format(score))
# Out:
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/kaggler/.local/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.353254 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977445	valid_1's ndcg@12: 0.849863
# [20]	training's ndcg@12: 0.977928	valid_1's ndcg@12: 0.850892
# [30]	training's ndcg@12: 0.978362	valid_1's ndcg@12: 0.851705
# [40]	training's ndcg@12: 0.97868	valid_1's ndcg@12: 0.851856
# [50]	training's ndcg@12: 0.978857	valid_1's ndcg@12: 0.852179
# [60]	training's ndcg@12: 0.97908	valid_1's ndcg@12: 0.8522
# [70]	training's ndcg@12: 0.979313	valid_1's ndcg@12: 0.852538
# [80]	training's ndcg@12: 0.979488	valid_1's ndcg@12: 0.852734
# [90]	training's ndcg@12: 0.979648	valid_1's ndcg@12: 0.853003
# [100]	training's ndcg@12: 0.979795	valid_1's ndcg@12: 0.853192
# [110]	training's ndcg@12: 0.979986	valid_1's ndcg@12: 0.853202
# [120]	training's ndcg@12: 0.980147	valid_1's ndcg@12: 0.853265
# [130]	training's ndcg@12: 0.980343	valid_1's ndcg@12: 0.853478
# [140]	training's ndcg@12: 0.980507	valid_1's ndcg@12: 0.853494
# [150]	training's ndcg@12: 0.980654	valid_1's ndcg@12: 0.853596
# [160]	training's ndcg@12: 0.980811	valid_1's ndcg@12: 0.853647
# [170]	training's ndcg@12: 0.980937	valid_1's ndcg@12: 0.853691
# [180]	training's ndcg@12: 0.981044	valid_1's ndcg@12: 0.853717
# [190]	training's ndcg@12: 0.981174	valid_1's ndcg@12: 0.853876
# [200]	training's ndcg@12: 0.981327	valid_1's ndcg@12: 0.853967
# [210]	training's ndcg@12: 0.981434	valid_1's ndcg@12: 0.854121
# [220]	training's ndcg@12: 0.981558	valid_1's ndcg@12: 0.854249
# [230]	training's ndcg@12: 0.981663	valid_1's ndcg@12: 0.854369
# [240]	training's ndcg@12: 0.98178	valid_1's ndcg@12: 0.854408
# [250]	training's ndcg@12: 0.981875	valid_1's ndcg@12: 0.854585
# [260]	training's ndcg@12: 0.981966	valid_1's ndcg@12: 0.854638
# [270]	training's ndcg@12: 0.982085	valid_1's ndcg@12: 0.854759
# [280]	training's ndcg@12: 0.982177	valid_1's ndcg@12: 0.85481
# [290]	training's ndcg@12: 0.98228	valid_1's ndcg@12: 0.854904
# [300]	training's ndcg@12: 0.982414	valid_1's ndcg@12: 0.854991
# [310]	training's ndcg@12: 0.982509	valid_1's ndcg@12: 0.855037
# [320]	training's ndcg@12: 0.98261	valid_1's ndcg@12: 0.855068
# [330]	training's ndcg@12: 0.9827	valid_1's ndcg@12: 0.855014
# [340]	training's ndcg@12: 0.982805	valid_1's ndcg@12: 0.855123
# [350]	training's ndcg@12: 0.982889	valid_1's ndcg@12: 0.855079
# [360]	training's ndcg@12: 0.983	valid_1's ndcg@12: 0.855194
# [370]	training's ndcg@12: 0.983087	valid_1's ndcg@12: 0.855263
# [380]	training's ndcg@12: 0.983179	valid_1's ndcg@12: 0.855375
# [390]	training's ndcg@12: 0.983268	valid_1's ndcg@12: 0.85542
# [400]	training's ndcg@12: 0.983352	valid_1's ndcg@12: 0.855368
# [410]	training's ndcg@12: 0.983432	valid_1's ndcg@12: 0.855399
# [420]	training's ndcg@12: 0.98355	valid_1's ndcg@12: 0.855385
# [430]	training's ndcg@12: 0.983638	valid_1's ndcg@12: 0.85541
# [440]	training's ndcg@12: 0.983725	valid_1's ndcg@12: 0.85545
# [450]	training's ndcg@12: 0.983813	valid_1's ndcg@12: 0.855486
# [460]	training's ndcg@12: 0.983898	valid_1's ndcg@12: 0.855507
# [470]	training's ndcg@12: 0.983979	valid_1's ndcg@12: 0.85562
# [480]	training's ndcg@12: 0.984071	valid_1's ndcg@12: 0.855659
# [490]	training's ndcg@12: 0.984141	valid_1's ndcg@12: 0.855689
# [500]	training's ndcg@12: 0.984211	valid_1's ndcg@12: 0.855742
# [510]	training's ndcg@12: 0.984299	valid_1's ndcg@12: 0.855667
# [520]	training's ndcg@12: 0.984372	valid_1's ndcg@12: 0.855633
# [530]	training's ndcg@12: 0.984433	valid_1's ndcg@12: 0.855724
# [540]	training's ndcg@12: 0.984513	valid_1's ndcg@12: 0.855794
# [550]	training's ndcg@12: 0.984579	valid_1's ndcg@12: 0.855847
# [560]	training's ndcg@12: 0.984649	valid_1's ndcg@12: 0.855804
# [570]	training's ndcg@12: 0.984734	valid_1's ndcg@12: 0.855846
# [580]	training's ndcg@12: 0.984794	valid_1's ndcg@12: 0.855869
# [590]	training's ndcg@12: 0.984849	valid_1's ndcg@12: 0.855907
# [600]	training's ndcg@12: 0.984916	valid_1's ndcg@12: 0.856023
# [610]	training's ndcg@12: 0.984978	valid_1's ndcg@12: 0.856091
# [620]	training's ndcg@12: 0.985062	valid_1's ndcg@12: 0.856113
# [630]	training's ndcg@12: 0.985112	valid_1's ndcg@12: 0.856148
# [640]	training's ndcg@12: 0.98518	valid_1's ndcg@12: 0.856136
# [650]	training's ndcg@12: 0.985244	valid_1's ndcg@12: 0.856121
# [660]	training's ndcg@12: 0.985308	valid_1's ndcg@12: 0.856069
# [670]	training's ndcg@12: 0.98538	valid_1's ndcg@12: 0.856125
# [680]	training's ndcg@12: 0.985452	valid_1's ndcg@12: 0.856121
# [690]	training's ndcg@12: 0.985517	valid_1's ndcg@12: 0.856133
# [700]	training's ndcg@12: 0.985572	valid_1's ndcg@12: 0.856219
# [710]	training's ndcg@12: 0.985631	valid_1's ndcg@12: 0.85621
# [720]	training's ndcg@12: 0.985687	valid_1's ndcg@12: 0.856182
# [730]	training's ndcg@12: 0.98575	valid_1's ndcg@12: 0.856166
# [740]	training's ndcg@12: 0.9858	valid_1's ndcg@12: 0.856233
# [750]	training's ndcg@12: 0.985857	valid_1's ndcg@12: 0.856195
# [760]	training's ndcg@12: 0.985911	valid_1's ndcg@12: 0.856267
# [770]	training's ndcg@12: 0.985978	valid_1's ndcg@12: 0.856266
# [780]	training's ndcg@12: 0.986053	valid_1's ndcg@12: 0.856377
# [790]	training's ndcg@12: 0.986113	valid_1's ndcg@12: 0.856386
# [800]	training's ndcg@12: 0.986166	valid_1's ndcg@12: 0.856362
# [810]	training's ndcg@12: 0.986217	valid_1's ndcg@12: 0.856359
# [820]	training's ndcg@12: 0.986268	valid_1's ndcg@12: 0.856352
# [830]	training's ndcg@12: 0.986323	valid_1's ndcg@12: 0.856299
# [840]	training's ndcg@12: 0.986378	valid_1's ndcg@12: 0.856336
# [850]	training's ndcg@12: 0.986429	valid_1's ndcg@12: 0.85644
# [860]	training's ndcg@12: 0.986483	valid_1's ndcg@12: 0.856434
# [870]	training's ndcg@12: 0.986548	valid_1's ndcg@12: 0.856445
# [880]	training's ndcg@12: 0.986608	valid_1's ndcg@12: 0.856383
# [890]	training's ndcg@12: 0.986667	valid_1's ndcg@12: 0.85635
# [900]	training's ndcg@12: 0.986726	valid_1's ndcg@12: 0.856355
# [910]	training's ndcg@12: 0.986771	valid_1's ndcg@12: 0.856276
# [920]	training's ndcg@12: 0.986821	valid_1's ndcg@12: 0.856304
# [930]	training's ndcg@12: 0.986866	valid_1's ndcg@12: 0.856242
# [940]	training's ndcg@12: 0.986921	valid_1's ndcg@12: 0.856241
# [950]	training's ndcg@12: 0.986984	valid_1's ndcg@12: 0.856246
# [960]	training's ndcg@12: 0.987032	valid_1's ndcg@12: 0.856231
# Early stopping, best iteration is:
# [868]	training's ndcg@12: 0.986534	valid_1's ndcg@12: 0.85647
# 0 0.03298677275758855
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=1, random_state=42 will be ignored. Current value: seed=1
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=1, random_state=42 will be ignored. Current value: seed=1
# [LightGBM] [Warning] seed is set=1, random_state=42 will be ignored. Current value: seed=1
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.134270 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977388	valid_1's ndcg@12: 0.849738
# [20]	training's ndcg@12: 0.978014	valid_1's ndcg@12: 0.850768
# [30]	training's ndcg@12: 0.978363	valid_1's ndcg@12: 0.85132
# [40]	training's ndcg@12: 0.978631	valid_1's ndcg@12: 0.851405
# [50]	training's ndcg@12: 0.97886	valid_1's ndcg@12: 0.851694
# [60]	training's ndcg@12: 0.97914	valid_1's ndcg@12: 0.851984
# [70]	training's ndcg@12: 0.979321	valid_1's ndcg@12: 0.852233
# [80]	training's ndcg@12: 0.979527	valid_1's ndcg@12: 0.852186
# [90]	training's ndcg@12: 0.979687	valid_1's ndcg@12: 0.852532
# [100]	training's ndcg@12: 0.979859	valid_1's ndcg@12: 0.852868
# [110]	training's ndcg@12: 0.980019	valid_1's ndcg@12: 0.852981
# [120]	training's ndcg@12: 0.980201	valid_1's ndcg@12: 0.853191
# [130]	training's ndcg@12: 0.980365	valid_1's ndcg@12: 0.853313
# [140]	training's ndcg@12: 0.980525	valid_1's ndcg@12: 0.853523
# [150]	training's ndcg@12: 0.980684	valid_1's ndcg@12: 0.853607
# [160]	training's ndcg@12: 0.980795	valid_1's ndcg@12: 0.853743
# [170]	training's ndcg@12: 0.980933	valid_1's ndcg@12: 0.853834
# [180]	training's ndcg@12: 0.981065	valid_1's ndcg@12: 0.853843
# [190]	training's ndcg@12: 0.981187	valid_1's ndcg@12: 0.853906
# [200]	training's ndcg@12: 0.98134	valid_1's ndcg@12: 0.854014
# [210]	training's ndcg@12: 0.981475	valid_1's ndcg@12: 0.854145
# [220]	training's ndcg@12: 0.981577	valid_1's ndcg@12: 0.854224
# [230]	training's ndcg@12: 0.981705	valid_1's ndcg@12: 0.854324
# [240]	training's ndcg@12: 0.981807	valid_1's ndcg@12: 0.854356
# [250]	training's ndcg@12: 0.98191	valid_1's ndcg@12: 0.854442
# [260]	training's ndcg@12: 0.981985	valid_1's ndcg@12: 0.854459
# [270]	training's ndcg@12: 0.982099	valid_1's ndcg@12: 0.854603
# [280]	training's ndcg@12: 0.98219	valid_1's ndcg@12: 0.854651
# [290]	training's ndcg@12: 0.982301	valid_1's ndcg@12: 0.85476
# [300]	training's ndcg@12: 0.982416	valid_1's ndcg@12: 0.854773
# [310]	training's ndcg@12: 0.982512	valid_1's ndcg@12: 0.854786
# [320]	training's ndcg@12: 0.98263	valid_1's ndcg@12: 0.854894
# [330]	training's ndcg@12: 0.982726	valid_1's ndcg@12: 0.854952
# [340]	training's ndcg@12: 0.982829	valid_1's ndcg@12: 0.854978
# [350]	training's ndcg@12: 0.982925	valid_1's ndcg@12: 0.855025
# [360]	training's ndcg@12: 0.983045	valid_1's ndcg@12: 0.85508
# [370]	training's ndcg@12: 0.983123	valid_1's ndcg@12: 0.855189
# [380]	training's ndcg@12: 0.983203	valid_1's ndcg@12: 0.855231
# [390]	training's ndcg@12: 0.983285	valid_1's ndcg@12: 0.85529
# [400]	training's ndcg@12: 0.983368	valid_1's ndcg@12: 0.855352
# [410]	training's ndcg@12: 0.983464	valid_1's ndcg@12: 0.855366
# [420]	training's ndcg@12: 0.983568	valid_1's ndcg@12: 0.855454
# [430]	training's ndcg@12: 0.983644	valid_1's ndcg@12: 0.855461
# [440]	training's ndcg@12: 0.983723	valid_1's ndcg@12: 0.855482
# [450]	training's ndcg@12: 0.983815	valid_1's ndcg@12: 0.855497
# [460]	training's ndcg@12: 0.983894	valid_1's ndcg@12: 0.855483
# [470]	training's ndcg@12: 0.983986	valid_1's ndcg@12: 0.855448
# [480]	training's ndcg@12: 0.984064	valid_1's ndcg@12: 0.855528
# [490]	training's ndcg@12: 0.984142	valid_1's ndcg@12: 0.85555
# [500]	training's ndcg@12: 0.984213	valid_1's ndcg@12: 0.855568
# [510]	training's ndcg@12: 0.984299	valid_1's ndcg@12: 0.855626
# [520]	training's ndcg@12: 0.984376	valid_1's ndcg@12: 0.855651
# [530]	training's ndcg@12: 0.984451	valid_1's ndcg@12: 0.855753
# [540]	training's ndcg@12: 0.984528	valid_1's ndcg@12: 0.855838
# [550]	training's ndcg@12: 0.984593	valid_1's ndcg@12: 0.855842
# [560]	training's ndcg@12: 0.984664	valid_1's ndcg@12: 0.855947
# [570]	training's ndcg@12: 0.984737	valid_1's ndcg@12: 0.855961
# [580]	training's ndcg@12: 0.98481	valid_1's ndcg@12: 0.855964
# [590]	training's ndcg@12: 0.984895	valid_1's ndcg@12: 0.855976
# [600]	training's ndcg@12: 0.984967	valid_1's ndcg@12: 0.856056
# [610]	training's ndcg@12: 0.985022	valid_1's ndcg@12: 0.856022
# [620]	training's ndcg@12: 0.985098	valid_1's ndcg@12: 0.856106
# [630]	training's ndcg@12: 0.985154	valid_1's ndcg@12: 0.856088
# [640]	training's ndcg@12: 0.985222	valid_1's ndcg@12: 0.856105
# [650]	training's ndcg@12: 0.985296	valid_1's ndcg@12: 0.856197
# [660]	training's ndcg@12: 0.985353	valid_1's ndcg@12: 0.856216
# [670]	training's ndcg@12: 0.985412	valid_1's ndcg@12: 0.856232
# [680]	training's ndcg@12: 0.985469	valid_1's ndcg@12: 0.856261
# [690]	training's ndcg@12: 0.985528	valid_1's ndcg@12: 0.856184
# [700]	training's ndcg@12: 0.985589	valid_1's ndcg@12: 0.856152
# [710]	training's ndcg@12: 0.985656	valid_1's ndcg@12: 0.856216
# [720]	training's ndcg@12: 0.985717	valid_1's ndcg@12: 0.856248
# [730]	training's ndcg@12: 0.985776	valid_1's ndcg@12: 0.856267
# [740]	training's ndcg@12: 0.985832	valid_1's ndcg@12: 0.856194
# [750]	training's ndcg@12: 0.985886	valid_1's ndcg@12: 0.856191
# [760]	training's ndcg@12: 0.985945	valid_1's ndcg@12: 0.856228
# [770]	training's ndcg@12: 0.986	valid_1's ndcg@12: 0.856273
# [780]	training's ndcg@12: 0.986054	valid_1's ndcg@12: 0.856314
# [790]	training's ndcg@12: 0.986112	valid_1's ndcg@12: 0.856239
# [800]	training's ndcg@12: 0.986177	valid_1's ndcg@12: 0.856288
# [810]	training's ndcg@12: 0.98623	valid_1's ndcg@12: 0.856286
# [820]	training's ndcg@12: 0.986286	valid_1's ndcg@12: 0.856324
# [830]	training's ndcg@12: 0.98634	valid_1's ndcg@12: 0.856302
# [840]	training's ndcg@12: 0.98639	valid_1's ndcg@12: 0.85635
# [850]	training's ndcg@12: 0.986447	valid_1's ndcg@12: 0.856333
# [860]	training's ndcg@12: 0.986479	valid_1's ndcg@12: 0.856299
# [870]	training's ndcg@12: 0.986538	valid_1's ndcg@12: 0.856258
# [880]	training's ndcg@12: 0.986591	valid_1's ndcg@12: 0.856341
# [890]	training's ndcg@12: 0.98665	valid_1's ndcg@12: 0.85622
# [900]	training's ndcg@12: 0.986693	valid_1's ndcg@12: 0.856288
# [910]	training's ndcg@12: 0.986742	valid_1's ndcg@12: 0.856332
# [920]	training's ndcg@12: 0.986786	valid_1's ndcg@12: 0.856289
# [930]	training's ndcg@12: 0.986842	valid_1's ndcg@12: 0.856382
# [940]	training's ndcg@12: 0.986885	valid_1's ndcg@12: 0.85641
# [950]	training's ndcg@12: 0.986939	valid_1's ndcg@12: 0.856343
# [960]	training's ndcg@12: 0.986995	valid_1's ndcg@12: 0.85635
# [970]	training's ndcg@12: 0.987046	valid_1's ndcg@12: 0.856287
# [980]	training's ndcg@12: 0.987095	valid_1's ndcg@12: 0.856305
# [990]	training's ndcg@12: 0.987149	valid_1's ndcg@12: 0.856341
# [1000]	training's ndcg@12: 0.987199	valid_1's ndcg@12: 0.856346
# [1010]	training's ndcg@12: 0.987254	valid_1's ndcg@12: 0.856398
# [1020]	training's ndcg@12: 0.987307	valid_1's ndcg@12: 0.856497
# [1030]	training's ndcg@12: 0.987359	valid_1's ndcg@12: 0.856464
# [1040]	training's ndcg@12: 0.987415	valid_1's ndcg@12: 0.856345
# [1050]	training's ndcg@12: 0.987466	valid_1's ndcg@12: 0.856392
# [1060]	training's ndcg@12: 0.987508	valid_1's ndcg@12: 0.85644
# [1070]	training's ndcg@12: 0.987555	valid_1's ndcg@12: 0.856367
# [1080]	training's ndcg@12: 0.987614	valid_1's ndcg@12: 0.856349
# [1090]	training's ndcg@12: 0.987657	valid_1's ndcg@12: 0.856328
# [1100]	training's ndcg@12: 0.987703	valid_1's ndcg@12: 0.856295
# [1110]	training's ndcg@12: 0.987759	valid_1's ndcg@12: 0.856279
# [1120]	training's ndcg@12: 0.987796	valid_1's ndcg@12: 0.856328
# Early stopping, best iteration is:
# [1023]	training's ndcg@12: 0.987321	valid_1's ndcg@12: 0.856512
# 1 0.033039762681372396
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=2, random_state=42 will be ignored. Current value: seed=2
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=2, random_state=42 will be ignored. Current value: seed=2
# [LightGBM] [Warning] seed is set=2, random_state=42 will be ignored. Current value: seed=2
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.098318 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977479	valid_1's ndcg@12: 0.8498
# [20]	training's ndcg@12: 0.977966	valid_1's ndcg@12: 0.851244
# [30]	training's ndcg@12: 0.978328	valid_1's ndcg@12: 0.851378
# [40]	training's ndcg@12: 0.978619	valid_1's ndcg@12: 0.851969
# [50]	training's ndcg@12: 0.978846	valid_1's ndcg@12: 0.852064
# [60]	training's ndcg@12: 0.97908	valid_1's ndcg@12: 0.852382
# [70]	training's ndcg@12: 0.97929	valid_1's ndcg@12: 0.852441
# [80]	training's ndcg@12: 0.979512	valid_1's ndcg@12: 0.852685
# [90]	training's ndcg@12: 0.979693	valid_1's ndcg@12: 0.852812
# [100]	training's ndcg@12: 0.979884	valid_1's ndcg@12: 0.852866
# [110]	training's ndcg@12: 0.980054	valid_1's ndcg@12: 0.85294
# [120]	training's ndcg@12: 0.980197	valid_1's ndcg@12: 0.853064
# [130]	training's ndcg@12: 0.980358	valid_1's ndcg@12: 0.853231
# [140]	training's ndcg@12: 0.98048	valid_1's ndcg@12: 0.853319
# [150]	training's ndcg@12: 0.980647	valid_1's ndcg@12: 0.853329
# [160]	training's ndcg@12: 0.980777	valid_1's ndcg@12: 0.853507
# [170]	training's ndcg@12: 0.980922	valid_1's ndcg@12: 0.85368
# [180]	training's ndcg@12: 0.981055	valid_1's ndcg@12: 0.85387
# [190]	training's ndcg@12: 0.981186	valid_1's ndcg@12: 0.853886
# [200]	training's ndcg@12: 0.981299	valid_1's ndcg@12: 0.854048
# [210]	training's ndcg@12: 0.981411	valid_1's ndcg@12: 0.854144
# [220]	training's ndcg@12: 0.981551	valid_1's ndcg@12: 0.854275
# [230]	training's ndcg@12: 0.98168	valid_1's ndcg@12: 0.854465
# [240]	training's ndcg@12: 0.981801	valid_1's ndcg@12: 0.854675
# [250]	training's ndcg@12: 0.981911	valid_1's ndcg@12: 0.854746
# [260]	training's ndcg@12: 0.982006	valid_1's ndcg@12: 0.85481
# [270]	training's ndcg@12: 0.982122	valid_1's ndcg@12: 0.854903
# [280]	training's ndcg@12: 0.982217	valid_1's ndcg@12: 0.854928
# [290]	training's ndcg@12: 0.982326	valid_1's ndcg@12: 0.855051
# [300]	training's ndcg@12: 0.982423	valid_1's ndcg@12: 0.855054
# [310]	training's ndcg@12: 0.982505	valid_1's ndcg@12: 0.855007
# [320]	training's ndcg@12: 0.982613	valid_1's ndcg@12: 0.855053
# [330]	training's ndcg@12: 0.982715	valid_1's ndcg@12: 0.855098
# [340]	training's ndcg@12: 0.982803	valid_1's ndcg@12: 0.855258
# [350]	training's ndcg@12: 0.982927	valid_1's ndcg@12: 0.855023
# [360]	training's ndcg@12: 0.98302	valid_1's ndcg@12: 0.855222
# [370]	training's ndcg@12: 0.983119	valid_1's ndcg@12: 0.855259
# [380]	training's ndcg@12: 0.983217	valid_1's ndcg@12: 0.855308
# [390]	training's ndcg@12: 0.983312	valid_1's ndcg@12: 0.855274
# [400]	training's ndcg@12: 0.98339	valid_1's ndcg@12: 0.855347
# [410]	training's ndcg@12: 0.983477	valid_1's ndcg@12: 0.85534
# [420]	training's ndcg@12: 0.983549	valid_1's ndcg@12: 0.855442
# [430]	training's ndcg@12: 0.983644	valid_1's ndcg@12: 0.855457
# [440]	training's ndcg@12: 0.983728	valid_1's ndcg@12: 0.855422
# [450]	training's ndcg@12: 0.983828	valid_1's ndcg@12: 0.855486
# [460]	training's ndcg@12: 0.983909	valid_1's ndcg@12: 0.85553
# [470]	training's ndcg@12: 0.983992	valid_1's ndcg@12: 0.855544
# [480]	training's ndcg@12: 0.984078	valid_1's ndcg@12: 0.855569
# [490]	training's ndcg@12: 0.98416	valid_1's ndcg@12: 0.855646
# [500]	training's ndcg@12: 0.984234	valid_1's ndcg@12: 0.855611
# [510]	training's ndcg@12: 0.984306	valid_1's ndcg@12: 0.85567
# [520]	training's ndcg@12: 0.984381	valid_1's ndcg@12: 0.855634
# [530]	training's ndcg@12: 0.984455	valid_1's ndcg@12: 0.855677
# [540]	training's ndcg@12: 0.984525	valid_1's ndcg@12: 0.855627
# [550]	training's ndcg@12: 0.984586	valid_1's ndcg@12: 0.855656
# [560]	training's ndcg@12: 0.984654	valid_1's ndcg@12: 0.855634
# [570]	training's ndcg@12: 0.984738	valid_1's ndcg@12: 0.855684
# [580]	training's ndcg@12: 0.984797	valid_1's ndcg@12: 0.855782
# [590]	training's ndcg@12: 0.984871	valid_1's ndcg@12: 0.855828
# [600]	training's ndcg@12: 0.984935	valid_1's ndcg@12: 0.855829
# [610]	training's ndcg@12: 0.985005	valid_1's ndcg@12: 0.855834
# [620]	training's ndcg@12: 0.985077	valid_1's ndcg@12: 0.855893
# [630]	training's ndcg@12: 0.985145	valid_1's ndcg@12: 0.855995
# [640]	training's ndcg@12: 0.985194	valid_1's ndcg@12: 0.855935
# [650]	training's ndcg@12: 0.985261	valid_1's ndcg@12: 0.855955
# [660]	training's ndcg@12: 0.985331	valid_1's ndcg@12: 0.855966
# [670]	training's ndcg@12: 0.985392	valid_1's ndcg@12: 0.855954
# [680]	training's ndcg@12: 0.98546	valid_1's ndcg@12: 0.855956
# [690]	training's ndcg@12: 0.985518	valid_1's ndcg@12: 0.855924
# [700]	training's ndcg@12: 0.985587	valid_1's ndcg@12: 0.856021
# [710]	training's ndcg@12: 0.985652	valid_1's ndcg@12: 0.856012
# [720]	training's ndcg@12: 0.98572	valid_1's ndcg@12: 0.856029
# [730]	training's ndcg@12: 0.985768	valid_1's ndcg@12: 0.855998
# [740]	training's ndcg@12: 0.98582	valid_1's ndcg@12: 0.856045
# [750]	training's ndcg@12: 0.985869	valid_1's ndcg@12: 0.856039
# [760]	training's ndcg@12: 0.98593	valid_1's ndcg@12: 0.856102
# [770]	training's ndcg@12: 0.985988	valid_1's ndcg@12: 0.856071
# [780]	training's ndcg@12: 0.98605	valid_1's ndcg@12: 0.856072
# [790]	training's ndcg@12: 0.9861	valid_1's ndcg@12: 0.856048
# [800]	training's ndcg@12: 0.986158	valid_1's ndcg@12: 0.85614
# [810]	training's ndcg@12: 0.986216	valid_1's ndcg@12: 0.85613
# [820]	training's ndcg@12: 0.986274	valid_1's ndcg@12: 0.85618
# [830]	training's ndcg@12: 0.986334	valid_1's ndcg@12: 0.856179
# [840]	training's ndcg@12: 0.986388	valid_1's ndcg@12: 0.856154
# [850]	training's ndcg@12: 0.986446	valid_1's ndcg@12: 0.856232
# [860]	training's ndcg@12: 0.986499	valid_1's ndcg@12: 0.856241
# [870]	training's ndcg@12: 0.986553	valid_1's ndcg@12: 0.856233
# [880]	training's ndcg@12: 0.986604	valid_1's ndcg@12: 0.856209
# [890]	training's ndcg@12: 0.986665	valid_1's ndcg@12: 0.856313
# [900]	training's ndcg@12: 0.986706	valid_1's ndcg@12: 0.856271
# [910]	training's ndcg@12: 0.986761	valid_1's ndcg@12: 0.856244
# [920]	training's ndcg@12: 0.986802	valid_1's ndcg@12: 0.856281
# [930]	training's ndcg@12: 0.986858	valid_1's ndcg@12: 0.856362
# [940]	training's ndcg@12: 0.986912	valid_1's ndcg@12: 0.856413
# [950]	training's ndcg@12: 0.986968	valid_1's ndcg@12: 0.856387
# [960]	training's ndcg@12: 0.987014	valid_1's ndcg@12: 0.856467
# [970]	training's ndcg@12: 0.987047	valid_1's ndcg@12: 0.856433
# [980]	training's ndcg@12: 0.987096	valid_1's ndcg@12: 0.856404
# [990]	training's ndcg@12: 0.987152	valid_1's ndcg@12: 0.856447
# [1000]	training's ndcg@12: 0.987194	valid_1's ndcg@12: 0.856433
# [1010]	training's ndcg@12: 0.987239	valid_1's ndcg@12: 0.856358
# [1020]	training's ndcg@12: 0.987285	valid_1's ndcg@12: 0.856438
# [1030]	training's ndcg@12: 0.987335	valid_1's ndcg@12: 0.856322
# [1040]	training's ndcg@12: 0.987385	valid_1's ndcg@12: 0.856357
# [1050]	training's ndcg@12: 0.987432	valid_1's ndcg@12: 0.856443
# [1060]	training's ndcg@12: 0.987481	valid_1's ndcg@12: 0.856495
# [1070]	training's ndcg@12: 0.987528	valid_1's ndcg@12: 0.856465
# [1080]	training's ndcg@12: 0.987569	valid_1's ndcg@12: 0.856448
# [1090]	training's ndcg@12: 0.987627	valid_1's ndcg@12: 0.856416
# [1100]	training's ndcg@12: 0.987678	valid_1's ndcg@12: 0.856412
# [1110]	training's ndcg@12: 0.987735	valid_1's ndcg@12: 0.856406
# [1120]	training's ndcg@12: 0.987779	valid_1's ndcg@12: 0.85641
# [1130]	training's ndcg@12: 0.98782	valid_1's ndcg@12: 0.856416
# [1140]	training's ndcg@12: 0.987855	valid_1's ndcg@12: 0.8564
# [1150]	training's ndcg@12: 0.987888	valid_1's ndcg@12: 0.856357
# [1160]	training's ndcg@12: 0.98794	valid_1's ndcg@12: 0.856348
# Early stopping, best iteration is:
# [1062]	training's ndcg@12: 0.987495	valid_1's ndcg@12: 0.8565
# 2 0.03302016029951503
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=3, random_state=42 will be ignored. Current value: seed=3
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=3, random_state=42 will be ignored. Current value: seed=3
# [LightGBM] [Warning] seed is set=3, random_state=42 will be ignored. Current value: seed=3
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.128999 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.97753	valid_1's ndcg@12: 0.850338
# [20]	training's ndcg@12: 0.978011	valid_1's ndcg@12: 0.851393
# [30]	training's ndcg@12: 0.978375	valid_1's ndcg@12: 0.851495
# [40]	training's ndcg@12: 0.978681	valid_1's ndcg@12: 0.851389
# [50]	training's ndcg@12: 0.978902	valid_1's ndcg@12: 0.851702
# [60]	training's ndcg@12: 0.979087	valid_1's ndcg@12: 0.85201
# [70]	training's ndcg@12: 0.97935	valid_1's ndcg@12: 0.852475
# [80]	training's ndcg@12: 0.979519	valid_1's ndcg@12: 0.852564
# [90]	training's ndcg@12: 0.979693	valid_1's ndcg@12: 0.852584
# [100]	training's ndcg@12: 0.979854	valid_1's ndcg@12: 0.852721
# [110]	training's ndcg@12: 0.980026	valid_1's ndcg@12: 0.85294
# [120]	training's ndcg@12: 0.980176	valid_1's ndcg@12: 0.853159
# [130]	training's ndcg@12: 0.980306	valid_1's ndcg@12: 0.853148
# [140]	training's ndcg@12: 0.980441	valid_1's ndcg@12: 0.853298
# [150]	training's ndcg@12: 0.980586	valid_1's ndcg@12: 0.853487
# [160]	training's ndcg@12: 0.980725	valid_1's ndcg@12: 0.853619
# [170]	training's ndcg@12: 0.980887	valid_1's ndcg@12: 0.853732
# [180]	training's ndcg@12: 0.981011	valid_1's ndcg@12: 0.853832
# [190]	training's ndcg@12: 0.981126	valid_1's ndcg@12: 0.853856
# [200]	training's ndcg@12: 0.981261	valid_1's ndcg@12: 0.853941
# [210]	training's ndcg@12: 0.981397	valid_1's ndcg@12: 0.854116
# [220]	training's ndcg@12: 0.98152	valid_1's ndcg@12: 0.854207
# [230]	training's ndcg@12: 0.981638	valid_1's ndcg@12: 0.854357
# [240]	training's ndcg@12: 0.981746	valid_1's ndcg@12: 0.854501
# [250]	training's ndcg@12: 0.981845	valid_1's ndcg@12: 0.854626
# [260]	training's ndcg@12: 0.98196	valid_1's ndcg@12: 0.854709
# [270]	training's ndcg@12: 0.982072	valid_1's ndcg@12: 0.854805
# [280]	training's ndcg@12: 0.9822	valid_1's ndcg@12: 0.854854
# [290]	training's ndcg@12: 0.982306	valid_1's ndcg@12: 0.854854
# [300]	training's ndcg@12: 0.982421	valid_1's ndcg@12: 0.854863
# [310]	training's ndcg@12: 0.982531	valid_1's ndcg@12: 0.85493
# [320]	training's ndcg@12: 0.982626	valid_1's ndcg@12: 0.854969
# [330]	training's ndcg@12: 0.982736	valid_1's ndcg@12: 0.85502
# [340]	training's ndcg@12: 0.982829	valid_1's ndcg@12: 0.855073
# [350]	training's ndcg@12: 0.982905	valid_1's ndcg@12: 0.855084
# [360]	training's ndcg@12: 0.983016	valid_1's ndcg@12: 0.85512
# [370]	training's ndcg@12: 0.983086	valid_1's ndcg@12: 0.855225
# [380]	training's ndcg@12: 0.983187	valid_1's ndcg@12: 0.855248
# [390]	training's ndcg@12: 0.98327	valid_1's ndcg@12: 0.855344
# [400]	training's ndcg@12: 0.983365	valid_1's ndcg@12: 0.855365
# [410]	training's ndcg@12: 0.98345	valid_1's ndcg@12: 0.855416
# [420]	training's ndcg@12: 0.983541	valid_1's ndcg@12: 0.855412
# [430]	training's ndcg@12: 0.983611	valid_1's ndcg@12: 0.855412
# [440]	training's ndcg@12: 0.983709	valid_1's ndcg@12: 0.855471
# [450]	training's ndcg@12: 0.983795	valid_1's ndcg@12: 0.855583
# [460]	training's ndcg@12: 0.983895	valid_1's ndcg@12: 0.855597
# [470]	training's ndcg@12: 0.983979	valid_1's ndcg@12: 0.855684
# [480]	training's ndcg@12: 0.984067	valid_1's ndcg@12: 0.855615
# [490]	training's ndcg@12: 0.984145	valid_1's ndcg@12: 0.855723
# [500]	training's ndcg@12: 0.984211	valid_1's ndcg@12: 0.855773
# [510]	training's ndcg@12: 0.984294	valid_1's ndcg@12: 0.855855
# [520]	training's ndcg@12: 0.984368	valid_1's ndcg@12: 0.855916
# [530]	training's ndcg@12: 0.984449	valid_1's ndcg@12: 0.856004
# [540]	training's ndcg@12: 0.984525	valid_1's ndcg@12: 0.855935
# [550]	training's ndcg@12: 0.984592	valid_1's ndcg@12: 0.855998
# [560]	training's ndcg@12: 0.984662	valid_1's ndcg@12: 0.856063
# [570]	training's ndcg@12: 0.984729	valid_1's ndcg@12: 0.856094
# [580]	training's ndcg@12: 0.984802	valid_1's ndcg@12: 0.856077
# [590]	training's ndcg@12: 0.984878	valid_1's ndcg@12: 0.85615
# [600]	training's ndcg@12: 0.984946	valid_1's ndcg@12: 0.856179
# [610]	training's ndcg@12: 0.985013	valid_1's ndcg@12: 0.856119
# [620]	training's ndcg@12: 0.985073	valid_1's ndcg@12: 0.856164
# [630]	training's ndcg@12: 0.985143	valid_1's ndcg@12: 0.856184
# [640]	training's ndcg@12: 0.985204	valid_1's ndcg@12: 0.856129
# [650]	training's ndcg@12: 0.985268	valid_1's ndcg@12: 0.856173
# [660]	training's ndcg@12: 0.98534	valid_1's ndcg@12: 0.856241
# [670]	training's ndcg@12: 0.985404	valid_1's ndcg@12: 0.856207
# [680]	training's ndcg@12: 0.985471	valid_1's ndcg@12: 0.856208
# [690]	training's ndcg@12: 0.985529	valid_1's ndcg@12: 0.856236
# [700]	training's ndcg@12: 0.985588	valid_1's ndcg@12: 0.856308
# [710]	training's ndcg@12: 0.985641	valid_1's ndcg@12: 0.856325
# [720]	training's ndcg@12: 0.9857	valid_1's ndcg@12: 0.856341
# [730]	training's ndcg@12: 0.985764	valid_1's ndcg@12: 0.856288
# [740]	training's ndcg@12: 0.985818	valid_1's ndcg@12: 0.856285
# [750]	training's ndcg@12: 0.985875	valid_1's ndcg@12: 0.856233
# [760]	training's ndcg@12: 0.985936	valid_1's ndcg@12: 0.856204
# [770]	training's ndcg@12: 0.985999	valid_1's ndcg@12: 0.856243
# [780]	training's ndcg@12: 0.986073	valid_1's ndcg@12: 0.856194
# [790]	training's ndcg@12: 0.986127	valid_1's ndcg@12: 0.856262
# [800]	training's ndcg@12: 0.986182	valid_1's ndcg@12: 0.856272
# [810]	training's ndcg@12: 0.98623	valid_1's ndcg@12: 0.856309
# [820]	training's ndcg@12: 0.986284	valid_1's ndcg@12: 0.856244
# Early stopping, best iteration is:
# [722]	training's ndcg@12: 0.985718	valid_1's ndcg@12: 0.856362
# 3 0.032970811196872146
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=4, random_state=42 will be ignored. Current value: seed=4
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=4, random_state=42 will be ignored. Current value: seed=4
# [LightGBM] [Warning] seed is set=4, random_state=42 will be ignored. Current value: seed=4
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.119017 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977327	valid_1's ndcg@12: 0.850184
# [20]	training's ndcg@12: 0.977894	valid_1's ndcg@12: 0.850981
# [30]	training's ndcg@12: 0.978329	valid_1's ndcg@12: 0.851126
# [40]	training's ndcg@12: 0.978641	valid_1's ndcg@12: 0.851707
# [50]	training's ndcg@12: 0.978854	valid_1's ndcg@12: 0.851789
# [60]	training's ndcg@12: 0.979049	valid_1's ndcg@12: 0.852131
# [70]	training's ndcg@12: 0.979225	valid_1's ndcg@12: 0.852455
# [80]	training's ndcg@12: 0.979448	valid_1's ndcg@12: 0.85267
# [90]	training's ndcg@12: 0.979581	valid_1's ndcg@12: 0.852864
# [100]	training's ndcg@12: 0.979766	valid_1's ndcg@12: 0.852893
# [110]	training's ndcg@12: 0.979954	valid_1's ndcg@12: 0.853005
# [120]	training's ndcg@12: 0.98016	valid_1's ndcg@12: 0.853229
# [130]	training's ndcg@12: 0.980328	valid_1's ndcg@12: 0.853288
# [140]	training's ndcg@12: 0.98047	valid_1's ndcg@12: 0.853442
# [150]	training's ndcg@12: 0.980633	valid_1's ndcg@12: 0.853635
# [160]	training's ndcg@12: 0.98077	valid_1's ndcg@12: 0.853775
# [170]	training's ndcg@12: 0.980896	valid_1's ndcg@12: 0.853897
# [180]	training's ndcg@12: 0.981016	valid_1's ndcg@12: 0.854006
# [190]	training's ndcg@12: 0.981121	valid_1's ndcg@12: 0.85411
# [200]	training's ndcg@12: 0.98127	valid_1's ndcg@12: 0.854193
# [210]	training's ndcg@12: 0.981401	valid_1's ndcg@12: 0.854225
# [220]	training's ndcg@12: 0.981523	valid_1's ndcg@12: 0.8543
# [230]	training's ndcg@12: 0.981628	valid_1's ndcg@12: 0.854411
# [240]	training's ndcg@12: 0.981748	valid_1's ndcg@12: 0.854331
# [250]	training's ndcg@12: 0.981885	valid_1's ndcg@12: 0.854412
# [260]	training's ndcg@12: 0.981989	valid_1's ndcg@12: 0.854573
# [270]	training's ndcg@12: 0.982115	valid_1's ndcg@12: 0.854742
# [280]	training's ndcg@12: 0.982197	valid_1's ndcg@12: 0.854768
# [290]	training's ndcg@12: 0.982319	valid_1's ndcg@12: 0.854975
# [300]	training's ndcg@12: 0.982418	valid_1's ndcg@12: 0.85493
# [310]	training's ndcg@12: 0.982522	valid_1's ndcg@12: 0.854982
# [320]	training's ndcg@12: 0.982624	valid_1's ndcg@12: 0.855053
# [330]	training's ndcg@12: 0.982731	valid_1's ndcg@12: 0.855073
# [340]	training's ndcg@12: 0.982824	valid_1's ndcg@12: 0.855173
# [350]	training's ndcg@12: 0.982927	valid_1's ndcg@12: 0.855263
# [360]	training's ndcg@12: 0.983018	valid_1's ndcg@12: 0.855349
# [370]	training's ndcg@12: 0.983122	valid_1's ndcg@12: 0.855377
# [380]	training's ndcg@12: 0.983197	valid_1's ndcg@12: 0.855566
# [390]	training's ndcg@12: 0.983291	valid_1's ndcg@12: 0.855601
# [400]	training's ndcg@12: 0.98339	valid_1's ndcg@12: 0.855584
# [410]	training's ndcg@12: 0.98348	valid_1's ndcg@12: 0.85566
# [420]	training's ndcg@12: 0.983568	valid_1's ndcg@12: 0.855679
# [430]	training's ndcg@12: 0.983654	valid_1's ndcg@12: 0.855694
# [440]	training's ndcg@12: 0.983733	valid_1's ndcg@12: 0.855691
# [450]	training's ndcg@12: 0.983819	valid_1's ndcg@12: 0.855752
# [460]	training's ndcg@12: 0.983906	valid_1's ndcg@12: 0.855818
# [470]	training's ndcg@12: 0.983969	valid_1's ndcg@12: 0.85585
# [480]	training's ndcg@12: 0.984041	valid_1's ndcg@12: 0.855879
# [490]	training's ndcg@12: 0.984114	valid_1's ndcg@12: 0.856008
# [500]	training's ndcg@12: 0.984203	valid_1's ndcg@12: 0.856054
# [510]	training's ndcg@12: 0.984283	valid_1's ndcg@12: 0.856047
# [520]	training's ndcg@12: 0.984362	valid_1's ndcg@12: 0.85612
# [530]	training's ndcg@12: 0.984432	valid_1's ndcg@12: 0.856105
# [540]	training's ndcg@12: 0.98451	valid_1's ndcg@12: 0.856157
# [550]	training's ndcg@12: 0.984579	valid_1's ndcg@12: 0.856215
# [560]	training's ndcg@12: 0.984663	valid_1's ndcg@12: 0.856213
# [570]	training's ndcg@12: 0.984736	valid_1's ndcg@12: 0.856291
# [580]	training's ndcg@12: 0.984811	valid_1's ndcg@12: 0.856274
# [590]	training's ndcg@12: 0.984884	valid_1's ndcg@12: 0.856195
# [600]	training's ndcg@12: 0.984952	valid_1's ndcg@12: 0.856233
# [610]	training's ndcg@12: 0.985026	valid_1's ndcg@12: 0.856257
# [620]	training's ndcg@12: 0.9851	valid_1's ndcg@12: 0.856273
# [630]	training's ndcg@12: 0.985166	valid_1's ndcg@12: 0.856252
# [640]	training's ndcg@12: 0.985234	valid_1's ndcg@12: 0.856287
# [650]	training's ndcg@12: 0.985307	valid_1's ndcg@12: 0.856336
# [660]	training's ndcg@12: 0.985357	valid_1's ndcg@12: 0.856407
# [670]	training's ndcg@12: 0.985419	valid_1's ndcg@12: 0.856454
# [680]	training's ndcg@12: 0.985461	valid_1's ndcg@12: 0.856447
# [690]	training's ndcg@12: 0.985526	valid_1's ndcg@12: 0.856483
# [700]	training's ndcg@12: 0.985584	valid_1's ndcg@12: 0.856518
# [710]	training's ndcg@12: 0.985646	valid_1's ndcg@12: 0.85655
# [720]	training's ndcg@12: 0.985699	valid_1's ndcg@12: 0.856483
# [730]	training's ndcg@12: 0.985756	valid_1's ndcg@12: 0.856574
# [740]	training's ndcg@12: 0.985814	valid_1's ndcg@12: 0.856638
# [750]	training's ndcg@12: 0.98588	valid_1's ndcg@12: 0.856595
# [760]	training's ndcg@12: 0.985929	valid_1's ndcg@12: 0.856546
# [770]	training's ndcg@12: 0.985986	valid_1's ndcg@12: 0.856562
# [780]	training's ndcg@12: 0.986049	valid_1's ndcg@12: 0.856586
# [790]	training's ndcg@12: 0.98611	valid_1's ndcg@12: 0.85649
# [800]	training's ndcg@12: 0.98619	valid_1's ndcg@12: 0.856576
# [810]	training's ndcg@12: 0.986242	valid_1's ndcg@12: 0.85658
# [820]	training's ndcg@12: 0.986303	valid_1's ndcg@12: 0.856585
# [830]	training's ndcg@12: 0.98636	valid_1's ndcg@12: 0.85651
# [840]	training's ndcg@12: 0.986416	valid_1's ndcg@12: 0.856561
# [850]	training's ndcg@12: 0.98649	valid_1's ndcg@12: 0.856625
# [860]	training's ndcg@12: 0.986545	valid_1's ndcg@12: 0.8566
# [870]	training's ndcg@12: 0.986591	valid_1's ndcg@12: 0.856602
# Early stopping, best iteration is:
# [775]	training's ndcg@12: 0.986015	valid_1's ndcg@12: 0.856643
# 4 0.03295051300879747
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=5, random_state=42 will be ignored. Current value: seed=5
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=5, random_state=42 will be ignored. Current value: seed=5
# [LightGBM] [Warning] seed is set=5, random_state=42 will be ignored. Current value: seed=5
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.181995 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977416	valid_1's ndcg@12: 0.849352
# [20]	training's ndcg@12: 0.978	valid_1's ndcg@12: 0.851259
# [30]	training's ndcg@12: 0.978357	valid_1's ndcg@12: 0.851843
# [40]	training's ndcg@12: 0.978644	valid_1's ndcg@12: 0.851907
# [50]	training's ndcg@12: 0.978882	valid_1's ndcg@12: 0.852166
# [60]	training's ndcg@12: 0.979094	valid_1's ndcg@12: 0.852165
# [70]	training's ndcg@12: 0.979329	valid_1's ndcg@12: 0.852561
# [80]	training's ndcg@12: 0.979555	valid_1's ndcg@12: 0.852752
# [90]	training's ndcg@12: 0.979701	valid_1's ndcg@12: 0.852924
# [100]	training's ndcg@12: 0.979869	valid_1's ndcg@12: 0.85294
# [110]	training's ndcg@12: 0.980018	valid_1's ndcg@12: 0.853076
# [120]	training's ndcg@12: 0.980187	valid_1's ndcg@12: 0.853161
# [130]	training's ndcg@12: 0.980333	valid_1's ndcg@12: 0.853303
# [140]	training's ndcg@12: 0.980461	valid_1's ndcg@12: 0.853494
# [150]	training's ndcg@12: 0.98062	valid_1's ndcg@12: 0.853652
# [160]	training's ndcg@12: 0.980754	valid_1's ndcg@12: 0.853768
# [170]	training's ndcg@12: 0.980896	valid_1's ndcg@12: 0.853842
# [180]	training's ndcg@12: 0.981	valid_1's ndcg@12: 0.854011
# [190]	training's ndcg@12: 0.981162	valid_1's ndcg@12: 0.854229
# [200]	training's ndcg@12: 0.981277	valid_1's ndcg@12: 0.854217
# [210]	training's ndcg@12: 0.981427	valid_1's ndcg@12: 0.854326
# [220]	training's ndcg@12: 0.981542	valid_1's ndcg@12: 0.854517
# [230]	training's ndcg@12: 0.981674	valid_1's ndcg@12: 0.854546
# [240]	training's ndcg@12: 0.98181	valid_1's ndcg@12: 0.854635
# [250]	training's ndcg@12: 0.981944	valid_1's ndcg@12: 0.854737
# [260]	training's ndcg@12: 0.98207	valid_1's ndcg@12: 0.854765
# [270]	training's ndcg@12: 0.982168	valid_1's ndcg@12: 0.854679
# [280]	training's ndcg@12: 0.982278	valid_1's ndcg@12: 0.854786
# [290]	training's ndcg@12: 0.982375	valid_1's ndcg@12: 0.854823
# [300]	training's ndcg@12: 0.982468	valid_1's ndcg@12: 0.854917
# [310]	training's ndcg@12: 0.982571	valid_1's ndcg@12: 0.854957
# [320]	training's ndcg@12: 0.982668	valid_1's ndcg@12: 0.854973
# [330]	training's ndcg@12: 0.982758	valid_1's ndcg@12: 0.85503
# [340]	training's ndcg@12: 0.982845	valid_1's ndcg@12: 0.855046
# [350]	training's ndcg@12: 0.982941	valid_1's ndcg@12: 0.855138
# [360]	training's ndcg@12: 0.983041	valid_1's ndcg@12: 0.855188
# [370]	training's ndcg@12: 0.983128	valid_1's ndcg@12: 0.855062
# [380]	training's ndcg@12: 0.983228	valid_1's ndcg@12: 0.855191
# [390]	training's ndcg@12: 0.983323	valid_1's ndcg@12: 0.855247
# [400]	training's ndcg@12: 0.983405	valid_1's ndcg@12: 0.855251
# [410]	training's ndcg@12: 0.983495	valid_1's ndcg@12: 0.855306
# [420]	training's ndcg@12: 0.983585	valid_1's ndcg@12: 0.855365
# [430]	training's ndcg@12: 0.983673	valid_1's ndcg@12: 0.855349
# [440]	training's ndcg@12: 0.983759	valid_1's ndcg@12: 0.855379
# [450]	training's ndcg@12: 0.983857	valid_1's ndcg@12: 0.855393
# [460]	training's ndcg@12: 0.98393	valid_1's ndcg@12: 0.855462
# [470]	training's ndcg@12: 0.984008	valid_1's ndcg@12: 0.855624
# [480]	training's ndcg@12: 0.984099	valid_1's ndcg@12: 0.855527
# [490]	training's ndcg@12: 0.984166	valid_1's ndcg@12: 0.855502
# [500]	training's ndcg@12: 0.984251	valid_1's ndcg@12: 0.85553
# [510]	training's ndcg@12: 0.984333	valid_1's ndcg@12: 0.855564
# [520]	training's ndcg@12: 0.984411	valid_1's ndcg@12: 0.855625
# [530]	training's ndcg@12: 0.984479	valid_1's ndcg@12: 0.855514
# [540]	training's ndcg@12: 0.984549	valid_1's ndcg@12: 0.855564
# [550]	training's ndcg@12: 0.98461	valid_1's ndcg@12: 0.855632
# [560]	training's ndcg@12: 0.984687	valid_1's ndcg@12: 0.85563
# [570]	training's ndcg@12: 0.984757	valid_1's ndcg@12: 0.855687
# [580]	training's ndcg@12: 0.984838	valid_1's ndcg@12: 0.855697
# [590]	training's ndcg@12: 0.984914	valid_1's ndcg@12: 0.855719
# [600]	training's ndcg@12: 0.984992	valid_1's ndcg@12: 0.855786
# [610]	training's ndcg@12: 0.985053	valid_1's ndcg@12: 0.855807
# [620]	training's ndcg@12: 0.985117	valid_1's ndcg@12: 0.85578
# [630]	training's ndcg@12: 0.985187	valid_1's ndcg@12: 0.855757
# [640]	training's ndcg@12: 0.985237	valid_1's ndcg@12: 0.855807
# [650]	training's ndcg@12: 0.985302	valid_1's ndcg@12: 0.855915
# [660]	training's ndcg@12: 0.985361	valid_1's ndcg@12: 0.855845
# [670]	training's ndcg@12: 0.985431	valid_1's ndcg@12: 0.855966
# [680]	training's ndcg@12: 0.985505	valid_1's ndcg@12: 0.855983
# [690]	training's ndcg@12: 0.985566	valid_1's ndcg@12: 0.855956
# [700]	training's ndcg@12: 0.985632	valid_1's ndcg@12: 0.856035
# [710]	training's ndcg@12: 0.985697	valid_1's ndcg@12: 0.856056
# [720]	training's ndcg@12: 0.985751	valid_1's ndcg@12: 0.856118
# [730]	training's ndcg@12: 0.985818	valid_1's ndcg@12: 0.856057
# [740]	training's ndcg@12: 0.985868	valid_1's ndcg@12: 0.856087
# [750]	training's ndcg@12: 0.985931	valid_1's ndcg@12: 0.856056
# [760]	training's ndcg@12: 0.98598	valid_1's ndcg@12: 0.856128
# [770]	training's ndcg@12: 0.986049	valid_1's ndcg@12: 0.856169
# [780]	training's ndcg@12: 0.986096	valid_1's ndcg@12: 0.856164
# [790]	training's ndcg@12: 0.986157	valid_1's ndcg@12: 0.856172
# [800]	training's ndcg@12: 0.986213	valid_1's ndcg@12: 0.856155
# [810]	training's ndcg@12: 0.986267	valid_1's ndcg@12: 0.856087
# [820]	training's ndcg@12: 0.986314	valid_1's ndcg@12: 0.856149
# [830]	training's ndcg@12: 0.986361	valid_1's ndcg@12: 0.85615
# [840]	training's ndcg@12: 0.986408	valid_1's ndcg@12: 0.856121
# [850]	training's ndcg@12: 0.986458	valid_1's ndcg@12: 0.856149
# [860]	training's ndcg@12: 0.986512	valid_1's ndcg@12: 0.856142
# [870]	training's ndcg@12: 0.986555	valid_1's ndcg@12: 0.856188
# [880]	training's ndcg@12: 0.986611	valid_1's ndcg@12: 0.856332
# [890]	training's ndcg@12: 0.986672	valid_1's ndcg@12: 0.856232
# [900]	training's ndcg@12: 0.986732	valid_1's ndcg@12: 0.856224
# [910]	training's ndcg@12: 0.986789	valid_1's ndcg@12: 0.856248
# [920]	training's ndcg@12: 0.98684	valid_1's ndcg@12: 0.856217
# [930]	training's ndcg@12: 0.986887	valid_1's ndcg@12: 0.856185
# [940]	training's ndcg@12: 0.986939	valid_1's ndcg@12: 0.856194
# [950]	training's ndcg@12: 0.986988	valid_1's ndcg@12: 0.856209
# [960]	training's ndcg@12: 0.987033	valid_1's ndcg@12: 0.85622
# [970]	training's ndcg@12: 0.987091	valid_1's ndcg@12: 0.856237
# [980]	training's ndcg@12: 0.987133	valid_1's ndcg@12: 0.856217
# Early stopping, best iteration is:
# [881]	training's ndcg@12: 0.986616	valid_1's ndcg@12: 0.856342
# 5 0.03297256613486885
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=6, random_state=42 will be ignored. Current value: seed=6
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=6, random_state=42 will be ignored. Current value: seed=6
# [LightGBM] [Warning] seed is set=6, random_state=42 will be ignored. Current value: seed=6
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.133016 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977329	valid_1's ndcg@12: 0.850344
# [20]	training's ndcg@12: 0.978087	valid_1's ndcg@12: 0.851436
# [30]	training's ndcg@12: 0.978322	valid_1's ndcg@12: 0.851576
# [40]	training's ndcg@12: 0.978673	valid_1's ndcg@12: 0.85199
# [50]	training's ndcg@12: 0.978912	valid_1's ndcg@12: 0.852152
# [60]	training's ndcg@12: 0.979132	valid_1's ndcg@12: 0.852361
# [70]	training's ndcg@12: 0.979335	valid_1's ndcg@12: 0.852536
# [80]	training's ndcg@12: 0.979535	valid_1's ndcg@12: 0.852626
# [90]	training's ndcg@12: 0.979689	valid_1's ndcg@12: 0.852769
# [100]	training's ndcg@12: 0.97985	valid_1's ndcg@12: 0.852867
# [110]	training's ndcg@12: 0.979994	valid_1's ndcg@12: 0.853002
# [120]	training's ndcg@12: 0.980152	valid_1's ndcg@12: 0.853121
# [130]	training's ndcg@12: 0.980316	valid_1's ndcg@12: 0.853159
# [140]	training's ndcg@12: 0.980477	valid_1's ndcg@12: 0.853233
# [150]	training's ndcg@12: 0.980608	valid_1's ndcg@12: 0.853359
# [160]	training's ndcg@12: 0.980758	valid_1's ndcg@12: 0.853361
# [170]	training's ndcg@12: 0.9809	valid_1's ndcg@12: 0.853532
# [180]	training's ndcg@12: 0.981019	valid_1's ndcg@12: 0.853647
# [190]	training's ndcg@12: 0.981149	valid_1's ndcg@12: 0.853695
# [200]	training's ndcg@12: 0.981274	valid_1's ndcg@12: 0.853717
# [210]	training's ndcg@12: 0.981413	valid_1's ndcg@12: 0.853845
# [220]	training's ndcg@12: 0.981527	valid_1's ndcg@12: 0.854037
# [230]	training's ndcg@12: 0.98164	valid_1's ndcg@12: 0.854243
# [240]	training's ndcg@12: 0.981757	valid_1's ndcg@12: 0.85429
# [250]	training's ndcg@12: 0.981859	valid_1's ndcg@12: 0.854286
# [260]	training's ndcg@12: 0.981985	valid_1's ndcg@12: 0.854447
# [270]	training's ndcg@12: 0.982114	valid_1's ndcg@12: 0.854596
# [280]	training's ndcg@12: 0.982235	valid_1's ndcg@12: 0.854537
# [290]	training's ndcg@12: 0.982341	valid_1's ndcg@12: 0.854526
# [300]	training's ndcg@12: 0.982448	valid_1's ndcg@12: 0.854604
# [310]	training's ndcg@12: 0.982567	valid_1's ndcg@12: 0.854673
# [320]	training's ndcg@12: 0.982659	valid_1's ndcg@12: 0.854688
# [330]	training's ndcg@12: 0.982758	valid_1's ndcg@12: 0.854702
# [340]	training's ndcg@12: 0.982851	valid_1's ndcg@12: 0.854778
# [350]	training's ndcg@12: 0.982945	valid_1's ndcg@12: 0.854874
# [360]	training's ndcg@12: 0.983032	valid_1's ndcg@12: 0.854941
# [370]	training's ndcg@12: 0.983128	valid_1's ndcg@12: 0.854907
# [380]	training's ndcg@12: 0.983215	valid_1's ndcg@12: 0.854979
# [390]	training's ndcg@12: 0.983303	valid_1's ndcg@12: 0.855035
# [400]	training's ndcg@12: 0.98341	valid_1's ndcg@12: 0.855114
# [410]	training's ndcg@12: 0.983499	valid_1's ndcg@12: 0.85522
# [420]	training's ndcg@12: 0.983585	valid_1's ndcg@12: 0.8553
# [430]	training's ndcg@12: 0.983674	valid_1's ndcg@12: 0.855431
# [440]	training's ndcg@12: 0.98375	valid_1's ndcg@12: 0.85547
# [450]	training's ndcg@12: 0.983835	valid_1's ndcg@12: 0.855453
# [460]	training's ndcg@12: 0.983932	valid_1's ndcg@12: 0.855413
# [470]	training's ndcg@12: 0.984002	valid_1's ndcg@12: 0.855507
# [480]	training's ndcg@12: 0.984104	valid_1's ndcg@12: 0.855573
# [490]	training's ndcg@12: 0.984182	valid_1's ndcg@12: 0.855569
# [500]	training's ndcg@12: 0.984263	valid_1's ndcg@12: 0.855543
# [510]	training's ndcg@12: 0.984343	valid_1's ndcg@12: 0.855664
# [520]	training's ndcg@12: 0.984418	valid_1's ndcg@12: 0.85564
# [530]	training's ndcg@12: 0.984492	valid_1's ndcg@12: 0.855722
# [540]	training's ndcg@12: 0.984563	valid_1's ndcg@12: 0.855763
# [550]	training's ndcg@12: 0.984634	valid_1's ndcg@12: 0.855875
# [560]	training's ndcg@12: 0.984704	valid_1's ndcg@12: 0.855927
# [570]	training's ndcg@12: 0.984776	valid_1's ndcg@12: 0.855897
# [580]	training's ndcg@12: 0.984854	valid_1's ndcg@12: 0.85588
# [590]	training's ndcg@12: 0.984912	valid_1's ndcg@12: 0.855848
# ...
# [650]	training's ndcg@12: 0.985297	valid_1's ndcg@12: 0.856011
# [660]	training's ndcg@12: 0.985381	valid_1's ndcg@12: 0.856049
# [670]	training's ndcg@12: 0.985458	valid_1's ndcg@12: 0.856079
# [680]	training's ndcg@12: 0.985515	valid_1's ndcg@12: 0.856085
# [690]	training's ndcg@12: 0.985565	valid_1's ndcg@12: 0.856154
# [700]	training's ndcg@12: 0.98562	valid_1's ndcg@12: 0.856099
# [710]	training's ndcg@12: 0.985665	valid_1's ndcg@12: 0.856145
# [720]	training's ndcg@12: 0.985724	valid_1's ndcg@12: 0.856145
# [730]	training's ndcg@12: 0.985788	valid_1's ndcg@12: 0.856108
# [740]	training's ndcg@12: 0.985863	valid_1's ndcg@12: 0.856102
# [750]	training's ndcg@12: 0.98592	valid_1's ndcg@12: 0.85613
# [760]	training's ndcg@12: 0.985979	valid_1's ndcg@12: 0.856162
# [770]	training's ndcg@12: 0.986033	valid_1's ndcg@12: 0.856208
# [780]	training's ndcg@12: 0.986085	valid_1's ndcg@12: 0.85616
# [790]	training's ndcg@12: 0.986137	valid_1's ndcg@12: 0.856159
# [800]	training's ndcg@12: 0.986202	valid_1's ndcg@12: 0.856152
# [810]	training's ndcg@12: 0.986257	valid_1's ndcg@12: 0.856146
# [820]	training's ndcg@12: 0.986312	valid_1's ndcg@12: 0.856202
# [830]	training's ndcg@12: 0.986365	valid_1's ndcg@12: 0.856205
# [840]	training's ndcg@12: 0.986417	valid_1's ndcg@12: 0.856212
# [850]	training's ndcg@12: 0.986475	valid_1's ndcg@12: 0.856233
# [860]	training's ndcg@12: 0.986523	valid_1's ndcg@12: 0.856239
# [870]	training's ndcg@12: 0.986572	valid_1's ndcg@12: 0.856264
# [880]	training's ndcg@12: 0.986632	valid_1's ndcg@12: 0.85622
# [890]	training's ndcg@12: 0.986673	valid_1's ndcg@12: 0.856109
# [900]	training's ndcg@12: 0.986731	valid_1's ndcg@12: 0.856208
# [910]	training's ndcg@12: 0.986768	valid_1's ndcg@12: 0.856175
# [920]	training's ndcg@12: 0.986821	valid_1's ndcg@12: 0.856185
# [930]	training's ndcg@12: 0.986874	valid_1's ndcg@12: 0.85615
# [940]	training's ndcg@12: 0.986933	valid_1's ndcg@12: 0.856327
# [950]	training's ndcg@12: 0.986972	valid_1's ndcg@12: 0.856406
# [960]	training's ndcg@12: 0.987015	valid_1's ndcg@12: 0.856381
# [970]	training's ndcg@12: 0.987066	valid_1's ndcg@12: 0.856399
# [980]	training's ndcg@12: 0.987114	valid_1's ndcg@12: 0.856481
# [990]	training's ndcg@12: 0.987168	valid_1's ndcg@12: 0.856446
# [1000]	training's ndcg@12: 0.987227	valid_1's ndcg@12: 0.856422
# [1010]	training's ndcg@12: 0.987276	valid_1's ndcg@12: 0.856401
# [1020]	training's ndcg@12: 0.987327	valid_1's ndcg@12: 0.856453
# [1030]	training's ndcg@12: 0.987383	valid_1's ndcg@12: 0.856385
# [1040]	training's ndcg@12: 0.987418	valid_1's ndcg@12: 0.856438
# [1050]	training's ndcg@12: 0.987462	valid_1's ndcg@12: 0.856449
# [1060]	training's ndcg@12: 0.98751	valid_1's ndcg@12: 0.856413
# [1070]	training's ndcg@12: 0.98755	valid_1's ndcg@12: 0.856473
# [1080]	training's ndcg@12: 0.987588	valid_1's ndcg@12: 0.856435
# Early stopping, best iteration is:
# [987]	training's ndcg@12: 0.987155	valid_1's ndcg@12: 0.856514
# 6 0.0330346471393437
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=7, random_state=42 will be ignored. Current value: seed=7
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=7, random_state=42 will be ignored. Current value: seed=7
# [LightGBM] [Warning] seed is set=7, random_state=42 will be ignored. Current value: seed=7
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.142214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977565	valid_1's ndcg@12: 0.84979
# [20]	training's ndcg@12: 0.97797	valid_1's ndcg@12: 0.850981
# [30]	training's ndcg@12: 0.978337	valid_1's ndcg@12: 0.851717
# [40]	training's ndcg@12: 0.978668	valid_1's ndcg@12: 0.851946
# [50]	training's ndcg@12: 0.978859	valid_1's ndcg@12: 0.852054
# [60]	training's ndcg@12: 0.979119	valid_1's ndcg@12: 0.852193
# [70]	training's ndcg@12: 0.979262	valid_1's ndcg@12: 0.852269
# [80]	training's ndcg@12: 0.979473	valid_1's ndcg@12: 0.852461
# [90]	training's ndcg@12: 0.979645	valid_1's ndcg@12: 0.852488
# [100]	training's ndcg@12: 0.979818	valid_1's ndcg@12: 0.852586
# [110]	training's ndcg@12: 0.980013	valid_1's ndcg@12: 0.852639
# [120]	training's ndcg@12: 0.980168	valid_1's ndcg@12: 0.852712
# [130]	training's ndcg@12: 0.980329	valid_1's ndcg@12: 0.852779
# [140]	training's ndcg@12: 0.980512	valid_1's ndcg@12: 0.85295
# [150]	training's ndcg@12: 0.980653	valid_1's ndcg@12: 0.853072
# [160]	training's ndcg@12: 0.980795	valid_1's ndcg@12: 0.853273
# [170]	training's ndcg@12: 0.980913	valid_1's ndcg@12: 0.853362
# [180]	training's ndcg@12: 0.981051	valid_1's ndcg@12: 0.853494
# [190]	training's ndcg@12: 0.981174	valid_1's ndcg@12: 0.853676
# [200]	training's ndcg@12: 0.981291	valid_1's ndcg@12: 0.853874
# [210]	training's ndcg@12: 0.981438	valid_1's ndcg@12: 0.853819
# [220]	training's ndcg@12: 0.981597	valid_1's ndcg@12: 0.853936
# [230]	training's ndcg@12: 0.981726	valid_1's ndcg@12: 0.854114
# [240]	training's ndcg@12: 0.981818	valid_1's ndcg@12: 0.854153
# [250]	training's ndcg@12: 0.981925	valid_1's ndcg@12: 0.854247
# [260]	training's ndcg@12: 0.98202	valid_1's ndcg@12: 0.854297
# [270]	training's ndcg@12: 0.982123	valid_1's ndcg@12: 0.854383
# [280]	training's ndcg@12: 0.982238	valid_1's ndcg@12: 0.854432
# [290]	training's ndcg@12: 0.982318	valid_1's ndcg@12: 0.854424
# [300]	training's ndcg@12: 0.982421	valid_1's ndcg@12: 0.854501
# [310]	training's ndcg@12: 0.982511	valid_1's ndcg@12: 0.85457
# [320]	training's ndcg@12: 0.982626	valid_1's ndcg@12: 0.854663
# [330]	training's ndcg@12: 0.982733	valid_1's ndcg@12: 0.854784
# [340]	training's ndcg@12: 0.982839	valid_1's ndcg@12: 0.854809
# [350]	training's ndcg@12: 0.98293	valid_1's ndcg@12: 0.854926
# [360]	training's ndcg@12: 0.983022	valid_1's ndcg@12: 0.855006
# [370]	training's ndcg@12: 0.983111	valid_1's ndcg@12: 0.855046
# [380]	training's ndcg@12: 0.983189	valid_1's ndcg@12: 0.85517
# [390]	training's ndcg@12: 0.983272	valid_1's ndcg@12: 0.855227
# [400]	training's ndcg@12: 0.983373	valid_1's ndcg@12: 0.855229
# [410]	training's ndcg@12: 0.983464	valid_1's ndcg@12: 0.855325
# [420]	training's ndcg@12: 0.983537	valid_1's ndcg@12: 0.855342
# [430]	training's ndcg@12: 0.983641	valid_1's ndcg@12: 0.855348
# [440]	training's ndcg@12: 0.983727	valid_1's ndcg@12: 0.855363
# [450]	training's ndcg@12: 0.983818	valid_1's ndcg@12: 0.855524
# [460]	training's ndcg@12: 0.983899	valid_1's ndcg@12: 0.85546
# [470]	training's ndcg@12: 0.983976	valid_1's ndcg@12: 0.855446
# [480]	training's ndcg@12: 0.984065	valid_1's ndcg@12: 0.85548
# [490]	training's ndcg@12: 0.984149	valid_1's ndcg@12: 0.855567
# [500]	training's ndcg@12: 0.98423	valid_1's ndcg@12: 0.855675
# [510]	training's ndcg@12: 0.984304	valid_1's ndcg@12: 0.855658
# [520]	training's ndcg@12: 0.984368	valid_1's ndcg@12: 0.85568
# [530]	training's ndcg@12: 0.984433	valid_1's ndcg@12: 0.855675
# [540]	training's ndcg@12: 0.984505	valid_1's ndcg@12: 0.855763
# [550]	training's ndcg@12: 0.984559	valid_1's ndcg@12: 0.855749
# [560]	training's ndcg@12: 0.984628	valid_1's ndcg@12: 0.855822
# [570]	training's ndcg@12: 0.984698	valid_1's ndcg@12: 0.855874
# [580]	training's ndcg@12: 0.984765	valid_1's ndcg@12: 0.855917
# [590]	training's ndcg@12: 0.984829	valid_1's ndcg@12: 0.855939
# [600]	training's ndcg@12: 0.984906	valid_1's ndcg@12: 0.855975
# [610]	training's ndcg@12: 0.984968	valid_1's ndcg@12: 0.855974
# [620]	training's ndcg@12: 0.985037	valid_1's ndcg@12: 0.856032
# [630]	training's ndcg@12: 0.985105	valid_1's ndcg@12: 0.856087
# [640]	training's ndcg@12: 0.985167	valid_1's ndcg@12: 0.856126
# [650]	training's ndcg@12: 0.98524	valid_1's ndcg@12: 0.856211
# [660]	training's ndcg@12: 0.985296	valid_1's ndcg@12: 0.856185
# [670]	training's ndcg@12: 0.985362	valid_1's ndcg@12: 0.856184
# [680]	training's ndcg@12: 0.985431	valid_1's ndcg@12: 0.85622
# [690]	training's ndcg@12: 0.985483	valid_1's ndcg@12: 0.856322
# [700]	training's ndcg@12: 0.985558	valid_1's ndcg@12: 0.856334
# [710]	training's ndcg@12: 0.985614	valid_1's ndcg@12: 0.856311
# [720]	training's ndcg@12: 0.985677	valid_1's ndcg@12: 0.856321
# [730]	training's ndcg@12: 0.985736	valid_1's ndcg@12: 0.856426
# [740]	training's ndcg@12: 0.9858	valid_1's ndcg@12: 0.85645
# [750]	training's ndcg@12: 0.985853	valid_1's ndcg@12: 0.856508
# [760]	training's ndcg@12: 0.985907	valid_1's ndcg@12: 0.856477
# [770]	training's ndcg@12: 0.985974	valid_1's ndcg@12: 0.856419
# [780]	training's ndcg@12: 0.986041	valid_1's ndcg@12: 0.856401
# [790]	training's ndcg@12: 0.986092	valid_1's ndcg@12: 0.856339
# [800]	training's ndcg@12: 0.986164	valid_1's ndcg@12: 0.856359
# [810]	training's ndcg@12: 0.986226	valid_1's ndcg@12: 0.856373
# [820]	training's ndcg@12: 0.986287	valid_1's ndcg@12: 0.856401
# [830]	training's ndcg@12: 0.986332	valid_1's ndcg@12: 0.856385
# [840]	training's ndcg@12: 0.986402	valid_1's ndcg@12: 0.856454
# [850]	training's ndcg@12: 0.986455	valid_1's ndcg@12: 0.856491
# Early stopping, best iteration is:
# [750]	training's ndcg@12: 0.985853	valid_1's ndcg@12: 0.856508
# 7 0.033013640695043804
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=8, random_state=42 will be ignored. Current value: seed=8
# [LightGBM] [Warning] seed is set=0, random_state=42 will be ignored. Current value: seed=0
# [LightGBM] [Warning] seed is set=8, random_state=42 will be ignored. Current value: seed=8
# [LightGBM] [Warning] seed is set=8, random_state=42 will be ignored. Current value: seed=8
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.112550 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12940
# [LightGBM] [Info] Number of data points in the train set: 785086, number of used features: 100
# Training until validation scores don't improve for 100 rounds
# [10]	training's ndcg@12: 0.977494	valid_1's ndcg@12: 0.849163
# [20]	training's ndcg@12: 0.978037	valid_1's ndcg@12: 0.850746
# [30]	training's ndcg@12: 0.978374	valid_1's ndcg@12: 0.851142
# [40]	training's ndcg@12: 0.978618	valid_1's ndcg@12: 0.851718
# [50]	training's ndcg@12: 0.978822	valid_1's ndcg@12: 0.851882
# [60]	training's ndcg@12: 0.979095	valid_1's ndcg@12: 0.852218
# [70]	training's ndcg@12: 0.979264	valid_1's ndcg@12: 0.852222
# [80]	training's ndcg@12: 0.979475	valid_1's ndcg@12: 0.852394
# [90]	training's ndcg@12: 0.979624	valid_1's ndcg@12: 0.852634
# [100]	training's ndcg@12: 0.97981	valid_1's ndcg@12: 0.852797
# [110]	training's ndcg@12: 0.979975	valid_1's ndcg@12: 0.852994
# [120]	training's ndcg@12: 0.980112	valid_1's ndcg@12: 0.85292
# [130]	training's ndcg@12: 0.980276	valid_1's ndcg@12: 0.853337
# [140]	training's ndcg@12: 0.98044	valid_1's ndcg@12: 0.853339
# [150]	training's ndcg@12: 0.980602	valid_1's ndcg@12: 0.853607
# [160]	training's ndcg@12: 0.980739	valid_1's ndcg@12: 0.853748
# [170]	training's ndcg@12: 0.980855	valid_1's ndcg@12: 0.853801
# [180]	training's ndcg@12: 0.981008	valid_1's ndcg@12: 0.853885
# [190]	training's ndcg@12: 0.981149	valid_1's ndcg@12: 0.853979
# [200]	training's ndcg@12: 0.981288	valid_1's ndcg@12: 0.854188
# [210]	training's ndcg@12: 0.981412	valid_1's ndcg@12: 0.854289
# [220]	training's ndcg@12: 0.981535	valid_1's ndcg@12: 0.8544
# [230]	training's ndcg@12: 0.981662	valid_1's ndcg@12: 0.854418
# [240]	training's ndcg@12: 0.981799	valid_1's ndcg@12: 0.854464
# [250]	training's ndcg@12: 0.981901	valid_1's ndcg@12: 0.854616
# [260]	training's ndcg@12: 0.982024	valid_1's ndcg@12: 0.854701
# [270]	training's ndcg@12: 0.98213	valid_1's ndcg@12: 0.854828
# [280]	training's ndcg@12: 0.982222	valid_1's ndcg@12: 0.854888
# [290]	training's ndcg@12: 0.982318	valid_1's ndcg@12: 0.854982
# [300]	training's ndcg@12: 0.98242	valid_1's ndcg@12: 0.855095
# [310]	training's ndcg@12: 0.982527	valid_1's ndcg@12: 0.855123
# [320]	training's ndcg@12: 0.982612	valid_1's ndcg@12: 0.855155
# [330]	training's ndcg@12: 0.982716	valid_1's ndcg@12: 0.855267
# [340]	training's ndcg@12: 0.982817	valid_1's ndcg@12: 0.855357
# [350]	training's ndcg@12: 0.982922	valid_1's ndcg@12: 0.855384
# [360]	training's ndcg@12: 0.983035	valid_1's ndcg@12: 0.855498
# [370]	training's ndcg@12: 0.983131	valid_1's ndcg@12: 0.855602
# [380]	training's ndcg@12: 0.983238	valid_1's ndcg@12: 0.855568
# [390]	training's ndcg@12: 0.983328	valid_1's ndcg@12: 0.85557
# [400]	training's ndcg@12: 0.983406	valid_1's ndcg@12: 0.855675
# [410]	training's ndcg@12: 0.98349	valid_1's ndcg@12: 0.855666
# [420]	training's ndcg@12: 0.98357	valid_1's ndcg@12: 0.855699
# [430]	training's ndcg@12: 0.983645	valid_1's ndcg@12: 0.855727
# [440]	training's ndcg@12: 0.983743	valid_1's ndcg@12: 0.855775
# [450]	training's ndcg@12: 0.983822	valid_1's ndcg@12: 0.85576
# [460]	training's ndcg@12: 0.983892	valid_1's ndcg@12: 0.85565
# [470]	training's ndcg@12: 0.983979	valid_1's ndcg@12: 0.855645
# [480]	training's ndcg@12: 0.98407	valid_1's ndcg@12: 0.855665
# [490]	training's ndcg@12: 0.98414	valid_1's ndcg@12: 0.855711
# [500]	training's ndcg@12: 0.984211	valid_1's ndcg@12: 0.85572
# [510]	training's ndcg@12: 0.984291	valid_1's ndcg@12: 0.855676
# [520]	training's ndcg@12: 0.984374	valid_1's ndcg@12: 0.855759
# [530]	training's ndcg@12: 0.984448	valid_1's ndcg@12: 0.855783
# [540]	training's ndcg@12: 0.984521	valid_1's ndcg@12: 0.855794
# [550]	training's ndcg@12: 0.984606	valid_1's ndcg@12: 0.855856
# [560]	training's ndcg@12: 0.98466	valid_1's ndcg@12: 0.856004
# [570]	training's ndcg@12: 0.984724	valid_1's ndcg@12: 0.855946
# [580]	training's ndcg@12: 0.984799	valid_1's ndcg@12: 0.856031
# [590]	training's ndcg@12: 0.984871	valid_1's ndcg@12: 0.856075
# [600]	training's ndcg@12: 0.98493	valid_1's ndcg@12: 0.856047
# [610]	training's ndcg@12: 0.98499	valid_1's ndcg@12: 0.856035
# [620]	training's ndcg@12: 0.985064	valid_1's ndcg@12: 0.856062
# [630]	training's ndcg@12: 0.985129	valid_1's ndcg@12: 0.856126
# [640]	training's ndcg@12: 0.985194	valid_1's ndcg@12: 0.856104
# [650]	training's ndcg@12: 0.985267	valid_1's ndcg@12: 0.856119
# [660]	training's ndcg@12: 0.985324	valid_1's ndcg@12: 0.856156
# [670]	training's ndcg@12: 0.985391	valid_1's ndcg@12: 0.856157
# [680]	training's ndcg@12: 0.985463	valid_1's ndcg@12: 0.85613
# [690]	training's ndcg@12: 0.985527	valid_1's ndcg@12: 0.85617
# [700]	training's ndcg@12: 0.985584	valid_1's ndcg@12: 0.856193
# [710]	training's ndcg@12: 0.985654	valid_1's ndcg@12: 0.856149
# [720]	training's ndcg@12: 0.985707	valid_1's ndcg@12: 0.856249
# [730]	training's ndcg@12: 0.985767	valid_1's ndcg@12: 0.85625
# [740]	training's ndcg@12: 0.985821	valid_1's ndcg@12: 0.856316
# [750]	training's ndcg@12: 0.985881	valid_1's ndcg@12: 0.856337
# [760]	training's ndcg@12: 0.985947	valid_1's ndcg@12: 0.856287
# [770]	training's ndcg@12: 0.986	valid_1's ndcg@12: 0.856288
# [780]	training's ndcg@12: 0.986068	valid_1's ndcg@12: 0.856257
# [790]	training's ndcg@12: 0.986127	valid_1's ndcg@12: 0.856178
# [800]	training's ndcg@12: 0.98619	valid_1's ndcg@12: 0.85627
# [810]	training's ndcg@12: 0.986246	valid_1's ndcg@12: 0.856296
# [820]	training's ndcg@12: 0.9863	valid_1's ndcg@12: 0.856281
# [830]	training's ndcg@12: 0.986356	valid_1's ndcg@12: 0.856263
# [840]	training's ndcg@12: 0.986421	valid_1's ndcg@12: 0.856408
# [850]	training's ndcg@12: 0.986473	valid_1's ndcg@12: 0.856341
# [860]	training's ndcg@12: 0.986534	valid_1's ndcg@12: 0.856287
# [870]	training's ndcg@12: 0.98657	valid_1's ndcg@12: 0.856295
# [880]	training's ndcg@12: 0.986621	valid_1's ndcg@12: 0.856187
# [890]	training's ndcg@12: 0.986672	valid_1's ndcg@12: 0.856271
# [900]	training's ndcg@12: 0.986726	valid_1's ndcg@12: 0.856288
# [910]	training's ndcg@12: 0.986786	valid_1's ndcg@12: 0.856333
# [920]	training's ndcg@12: 0.986844	valid_1's ndcg@12: 0.85636
# [930]	training's ndcg@12: 0.98689	valid_1's ndcg@12: 0.856348
# Early stopping, best iteration is:
# [838]	training's ndcg@12: 0.986416	valid_1's ndcg@12: 0.85642
# 8 0.03302368945430626
# MAP@12 : 0.03302

# %%
scores
# Out:
# [0.03298677275758855,
#  0.033039762681372396,
#  0.03302016029951503,
#  0.032970811196872146,
#  0.03295051300879747,
#  0.03297256613486885,
#  0.0330346471393437,
#  0.033013640695043804,
#  0.03302368945430626]

# %%
fi_n = fi['feature'].nunique()
order = list(fi.groupby("feature").mean().sort_values("importance", ascending=False).index)
plt.figure(figsize=(10, fi_n*0.2))
sns.barplot(x="importance", y="feature", data=fi, order=order)
plt.title(f"LGBM importance")
plt.tight_layout()
plt.savefig(OUTPUT_DIR + f'{exp_name}/lgbm_importance.png')

# %%
del history_tran, target_tran, target_id, recom
del ml_train, ml_valid, tr_x, tr_y, vl_x, vl_y, tr_data, vl_data, valid, valid_pred
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20983/1474484115.py in <module>
# ----> 1 del history_tran, target_tran, target_id, recom
#       2 del ml_train, ml_valid, tr_x, tr_y, vl_x, vl_y, tr_data, vl_data, valid, valid_pred
#       3 gc.collect()
#
# NameError: name 'recom' is not defined

# %% [markdown]
# # sub

# %%
if RUN_INF:
    N_ITER = 9
    # テストデータの作成
    all_target_id = sample['customer_id'].tolist()
    first_week_sales_pred_tmp = first_week_sales_pred[first_week_sales_pred['1st_week_sales_dat'] >= '2020/09/23']

    # メモリのケアのためバッチで推論を回す
    batchs = [all_target_id[i:i+BATCH_SIZE] for i in range(0, len(all_target_id), BATCH_SIZE)]
    
    preds = []
    
    for target_id in batchs:
        recom = get_reccomend(target_id, transactions, Ns, first_week_sales_pred_tmp)
        ml_test = add_features(recom, transactions, articles, customers, first_week_sales_pred_tmp)

        test_pred = np.zeros(len(ml_test))
        models = pathlib.Path(OUTPUT_DIR + f'{exp_name}').glob('model*.pickle')

        for m in models:
            with open(m, 'rb') as f:
                model = pickle.load(f)
        test_pred += model.predict(ml_test[features], num_iteration=model.best_iteration) / N_ITER

        test = ml_test[['customer_id', 'article_id']].copy()
        test['prob'] = test_pred
        test = test.sort_values(['customer_id', 'prob'], ascending=False)
        test = test.groupby('customer_id').head(12)
        preds.append(test)
    
    del recom, ml_test, test_pred
    gc.collect()

    test = pd.concat(preds)
    test['article_id'] = test['article_id'].map(article_ids)
    test['customer_id'] = test['customer_id'].map(customer_ids)

    test = test.groupby('customer_id')['article_id'].apply(list).reset_index()

    sub = sample['customer_id'].map(customer_ids).to_frame()
    sub = sub.merge(test, on=['customer_id'], how='left')
    sub = sub.rename(columns={'article_id':'prediction'})
    assert(sub['prediction'].apply(len).min()==12)
    sub['prediction'] = sub['prediction'].apply(lambda x: ' '.join(x))
    sub.to_csv(OUTPUT_DIR + f'{exp_name}/{exp_name}_sub.csv', index=False)
# Out:
# /tmp/ipykernel_20983/3859029819.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_week_sales_pred['new_article'] = 1

# %%
message = f'{exp_name} is finished!\nvalid_score : {cv_score}'
line_notify.send(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31107/2025811709.py in <module>
# ----> 1 message = f'{exp_name} is finished!\nvalid_score : {cv_score}'
#       2 line_notify.send(message)
#
# NameError: name 'cv_score' is not defined
